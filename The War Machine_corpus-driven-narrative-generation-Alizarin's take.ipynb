# %% [markdown]
# # The War Machine
# ## War novel generator
#
# By [Alizarinz](http://www.alizarinz.com/)
#
# Based on some of the best and most absurd war novels by mostly American authors + related handpicked literature.
#
# Including masterpieces by:
#
# ### Bukowski  |  Heller  |  Vonnegut  |  Barth  |  Orwell  |
#
# And all the war novels available on wikiplots!
#
# ## Foreword
# The War Machine is a brain-blending journey into the depths of a computer-generated war narrative. Not conventionally coherent, this ironic nightmare of a war-story is true to reality like no other. As cryptic as a homeless veteran on the train, The War Machine speaks in the insane voice of war trauma.
# Trained on a corpus of dozens of war novels, seasoned with handpicked related literature,  The War Machine is a disturbingly violent text. Elusive, confusing and perverted, this computer-generated prose might not tell a kind of story a human strain of thought can follow. Nonetheless, it does a pretty good job of portraying a realistic state of the world, fractured by wars. Because In the end of the day, who’s more trained than than the machine itself to write war novels?
#
#
# The code is based on "# A few simple corpus-driven approaches to narrative analysis and generation" notebook by [Allison Parrish](http://www.decontextualize.com/).

# %% [markdown]
# # A few simple corpus-driven approaches to narrative analysis and generation
#
# By [Allison Parrish](http://www.decontextualize.com/)
#
# This notebook is a fast introduction to a few techniques for working with narrative corpora. By "narrative corpora," I mean pre-existing bodies of text that mostly contain the texts of narratives. In particular, we're going to use Mark Riedl's [WikiPlots corpus](https://github.com/markriedl/WikiPlots), which has the titles and plot summaries of more than one hundred thousand movies, books, television shows and other media from Wikipedia.
#
# The notebook takes you through using [spaCy](http://spacy.io) to extract words, noun chunks, parts of speech and entities from the text and then sew them back together with [Tracery](http://tracery.io). It then shows how to use [Markovify](https://github.com/jsvine/markovify) to create new narratives from existing narrative text, along with a quick example of recurrent neural network text generation with [textgenrnn](https://github.com/minimaxir/textgenrnn).
#
# The code is written in Python, but you don't really need to know Python in order to use the notebook. Everything's pre-written for you, so you can just execute the cells, making small changes to the code as needed. Even if the notebook itself doesn't end up being useful to you, hopefully it spurs a few ideas that you can take with you into your practice as a storyteller and/or programmer.

# %% [markdown]
# ## Loading the corpus
#
# The first step is to get the narrative corpus into the program. Because WikiPlots is so big, we're actually going to be working with a smaller subset: only the plot summaries for romantic comedy movies. The subcorpus was made using [this notebook on creating a subcorpus of WikiPlots](https://github.com/aparrish/corpus-driven-narrative-generation/blob/master/creating-a-wikiplots-subcorpus.ipynb), which you can consult if you want to make your own with a different subset of WikiPlots.
#
# The corpus we're working with takes the form of a TSV file ("tab separated values"), with each line containing the title of the movie, a number indicating where in the plot summary the sentence for this line occurs, the total number of sentences in the summary, and the actual text of the sentence. The following cell loads the data into a list of dictionaries:

# %% [markdown]
# ## How to load a custom corpus
#
# Maybe[this text to tsv converter](https://onlinetsvtools.com/convert-text-to-tsv)

# %%
sentences = []
for line in open("war_plot_sentences.tsv"):
    line = line.strip()
    items = line.split("\t")
    sentences.append(
        {'title': items[0],
         'index': int(items[1]),
         'total': int(items[2]),
         'text': items[3]})

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
goat_sents = []
doc = nlp(open("./ep-the-men-who-stare-at-goats.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    goat_sents.append(
        {'title': "goats",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
kite_sents = []
doc = nlp(open("./ep-the_kite_runner.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    kite_sents.append(
        {'title': "kite",
         'index': i,
         'total': len(sents),
         'text': sent.text.replace("\r",""),
         'text': sent.text.strip("\n"),
         'text': sent.text.replace("\n"," "),
         'text': sent.text.rstrip("\n"),
         'text': sent.text.strip()})

# %%
johnny_sents = []
doc = nlp(open("./ep-Johnny-Got-His-Gun.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    johnny_sents.append(
        {'title': "johnny",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
catalonia_sents = []
doc = nlp(open("./ep-homagecatalonia.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    catalonia_sents.append(
        {'title': "catalonia",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
western_sents = []
doc = nlp(open("./ep-All Quiet on the Western Front.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    western_sents.append(
        {'title': "",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
tolls_sents = []
doc = nlp(open("./ep-FOR WHOM  THE BELL TOLLS.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    tolls_sents.append(
        {'title': "",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
floating_sents = []
doc = nlp(open("./ep-floating-opera.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    floating_sents.append(
        {'title': "floating",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
factotum_sents = []
doc = nlp(open("./ep-Factotum - Charles Bukowski.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    factotum_sents.append(
        {'title': "factotum",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
catch_sents = []
doc = nlp(open("./ep-catch-22.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    catch_sents.append(
        {'title': "catch22",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
slaughterhouse_sents = []
doc = nlp(open("./ep-slaughterhouse - five.txt").read())
sents = list(doc.sents)
for i, sent in enumerate(sents):
    slaughterhouse_sents.append(
        {'title': "slaughterhouse",
         'index': i,
         'total': len(sents),
         'text': sent.text.strip()})

# %%
slaughterhouse_sents
# Out:
# [{'title': 'slaughterhouse',
#   'index': 0,
#   'total': 4415,
#   'text': 'SLAUGHTERHOUSE-FIVE'},
#  {'title': 'slaughterhouse',
#   'index': 1,
#   'total': 4415,
#   'text': 'This is a novel somewhat in the telegraphic schizophrenic manner of tales of the planet Tralfamadore, where the flying saucers come from.'},
#  {'title': 'slaughterhouse', 'index': 2, 'total': 4415, 'text': 'Peace.'},
#  {'title': 'slaughterhouse', 'index': 3, 'total': 4415, 'text': 'One'},
#  {'title': 'slaughterhouse',
#   'index': 4,
#   'total': 4415,
#   'text': 'All this happened, more or less.'},
#  {'title': 'slaughterhouse',
#   'index': 5,
#   'total': 4415,
#   'text': 'The war parts, anyway, are pretty much true.'},
#  {'title': 'slaughterhouse', 'index': 6, 'total': 4415, 'text': 'One guy'},
#  {'title': 'slaughterhouse',
#   'index': 7,
#   'total': 4415,
#   'text': 'I  knew really was shot in Dresden for taking a teapot that wasn’t his.'},
#  {'title': 'slaughterhouse',
#   'index': 8,
#   'total': 4415,
#   'text': 'Another guy I knew really did threaten to have his personal enemies killed by hired gunmen after the war.'},
#  {'title': 'slaughterhouse', 'index': 9, 'total': 4415, 'text': 'And so on.'},
#  {'title': 'slaughterhouse',
#   'index': 10,
#   'total': 4415,
#   'text': "I've changed all the names."},
#  {'title': 'slaughterhouse',
#   'index': 11,
#   'total': 4415,
#   'text': 'I really did go back to Dresden with Guggenheim money (God love it) in 1967.'},
#  {'title': 'slaughterhouse',
#   'index': 12,
#   'total': 4415,
#   'text': 'It looked a lot like Dayton, Ohio, more open spaces than Dayton has.'},
#  {'title': 'slaughterhouse',
#   'index': 13,
#   'total': 4415,
#   'text': 'There must be tons of human bone meal in the ground.'},
#  {'title': 'slaughterhouse',
#   'index': 14,
#   'total': 4415,
#   'text': "I went back there with an old war buddy, Bernard V. O'Hare, and we made friends with a taxi driver, who took us to the slaughterhouse where we had been locked up at night as prisoner of war."},
#  {'title': 'slaughterhouse',
#   'index': 15,
#   'total': 4415,
#   'text': 'His name was Gerhard Muller.'},
#  {'title': 'slaughterhouse',
#   'index': 16,
#   'total': 4415,
#   'text': 'He told us that he was a prisoner of the Americans for a while.'},
#  {'title': 'slaughterhouse',
#   'index': 17,
#   'total': 4415,
#   'text': "We asked him how it was to live under Communism, and he said that it was terrible at first, because everybody had to work so hard, and because there wasn't much shelter or food or clothing."},
#  {'title': 'slaughterhouse',
#   'index': 18,
#   'total': 4415,
#   'text': 'But things were much better now.'},
#  {'title': 'slaughterhouse',
#   'index': 19,
#   'total': 4415,
#   'text': 'He had a pleasant little apartment, and his daughter was getting an excellent education.'},
#  {'title': 'slaughterhouse',
#   'index': 20,
#   'total': 4415,
#   'text': 'His mother was incinerated in the Dresden fire-storm.'},
#  {'title': 'slaughterhouse',
#   'index': 21,
#   'total': 4415,
#   'text': 'So it goes.'},
#  {'title': 'slaughterhouse',
#   'index': 22,
#   'total': 4415,
#   'text': "He sent O'Hare a postcard at Christmastime, and here is what it said: 'I wish you and your family also as to your friend Merry Christmas and a happy New Year"},
#  {'title': 'slaughterhouse',
#   'index': 23,
#   'total': 4415,
#   'text': 'and I hope that we’ll meet again in a world of peace and freedom in the taxi cab if the accident will.'},
#  {'title': 'slaughterhouse', 'index': 24, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 25,
#   'total': 4415,
#   'text': "I like that very much: '"},
#  {'title': 'slaughterhouse',
#   'index': 26,
#   'total': 4415,
#   'text': 'If the accident will.'},
#  {'title': 'slaughterhouse', 'index': 27, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 28,
#   'total': 4415,
#   'text': 'I would hate to tell you what this lousy little book cost me in money and anxiety and time.'},
#  {'title': 'slaughterhouse',
#   'index': 29,
#   'total': 4415,
#   'text': 'When I got home from the Second World War twenty-three years ago, I thought it would be easy for me to write about the destruction of Dresden, since all I would have to do would be to report what I had seen.'},
#  {'title': 'slaughterhouse',
#   'index': 30,
#   'total': 4415,
#   'text': 'And I thought, too, that it would be a masterpiece or at least make me a lot of money, since the subject was so big.'},
#  {'title': 'slaughterhouse',
#   'index': 31,
#   'total': 4415,
#   'text': 'But not many words about Dresden came from my mind then-not enough of them to make a book, anyway.'},
#  {'title': 'slaughterhouse',
#   'index': 32,
#   'total': 4415,
#   'text': 'And not many words come now, either, when I have become an old fart with his memories and his Pall Malls, with his sons full grown.'},
#  {'title': 'slaughterhouse',
#   'index': 33,
#   'total': 4415,
#   'text': 'I think of how useless the Dresden-part of my memory has been, and yet how tempting Dresden has been to write about, and I am reminded of the famous limerick'},
#  {'title': 'slaughterhouse',
#   'index': 34,
#   'total': 4415,
#   'text': ": There was a young man from Stamboul, Who soliloquized thus to his tool, 'You took all my wealth"},
#  {'title': 'slaughterhouse',
#   'index': 35,
#   'total': 4415,
#   'text': 'And you ruined my health,'},
#  {'title': 'slaughterhouse',
#   'index': 36,
#   'total': 4415,
#   'text': "And now you won't pee,"},
#  {'title': 'slaughterhouse',
#   'index': 37,
#   'total': 4415,
#   'text': 'you old fool ’'},
#  {'title': 'slaughterhouse',
#   'index': 38,
#   'total': 4415,
#   'text': "And I'm reminded, too, of the song that goes"},
#  {'title': 'slaughterhouse',
#   'index': 39,
#   'total': 4415,
#   'text': 'My name is Yon Yonson'},
#  {'title': 'slaughterhouse',
#   'index': 40,
#   'total': 4415,
#   'text': ', I work in Wisconsin, I work in a lumbermill there.'},
#  {'title': 'slaughterhouse',
#   'index': 41,
#   'total': 4415,
#   'text': "The people I meet when I walk down the street, They say, 'What's your name?"},
#  {'title': 'slaughterhouse', 'index': 42, 'total': 4415, 'text': 'And I say,'},
#  {'title': 'slaughterhouse', 'index': 43, 'total': 4415, 'text': '‘'},
#  {'title': 'slaughterhouse',
#   'index': 44,
#   'total': 4415,
#   'text': 'My name is Yon Yonson, I work in Wisconsin...'},
#  {'title': 'slaughterhouse',
#   'index': 45,
#   'total': 4415,
#   'text': 'And so on to infinity.'},
#  {'title': 'slaughterhouse',
#   'index': 46,
#   'total': 4415,
#   'text': "Over the years, people I've met have often asked me what I'm working on, and I've usually replied that the main thing was a book about Dresden."},
#  {'title': 'slaughterhouse',
#   'index': 47,
#   'total': 4415,
#   'text': "I said that to Harrison Starr, the movie-maker, one time, and he raised his eyebrows and inquired, 'Is it an anti-war book?' '"},
#  {'title': 'slaughterhouse',
#   'index': 48,
#   'total': 4415,
#   'text': "Yes,' I said. '"},
#  {'title': 'slaughterhouse', 'index': 49, 'total': 4415, 'text': 'I guess.'},
#  {'title': 'slaughterhouse', 'index': 50, 'total': 4415, 'text': "’ '"},
#  {'title': 'slaughterhouse',
#   'index': 51,
#   'total': 4415,
#   'text': "You know what I say to people when I hear they're writing anti-war books?' '"},
#  {'title': 'slaughterhouse', 'index': 52, 'total': 4415, 'text': 'No.'},
#  {'title': 'slaughterhouse',
#   'index': 53,
#   'total': 4415,
#   'text': 'What do you say, Harrison Starr?'},
#  {'title': 'slaughterhouse', 'index': 54, 'total': 4415, 'text': "’ '"},
#  {'title': 'slaughterhouse',
#   'index': 55,
#   'total': 4415,
#   'text': 'I say, "Why don’t you write an anti-glacier book instead?'},
#  {'title': 'slaughterhouse',
#   'index': 56,
#   'total': 4415,
#   'text': '"’ What he meant, of course, was that there would always be wars, that they were as easy to stop as glaciers.'},
#  {'title': 'slaughterhouse',
#   'index': 57,
#   'total': 4415,
#   'text': 'I believe that too.'},
#  {'title': 'slaughterhouse',
#   'index': 58,
#   'total': 4415,
#   'text': 'And, even if wars didn’t keep coming like glaciers, there would still be plain old death.'},
#  {'title': 'slaughterhouse',
#   'index': 59,
#   'total': 4415,
#   'text': "When I was somewhat younger, working on my famous Dresden book, I asked an old war buddy named Bernard V. O'Hare if I could come to see him."},
#  {'title': 'slaughterhouse',
#   'index': 60,
#   'total': 4415,
#   'text': 'He was a district attorney in Pennsylvania.'},
#  {'title': 'slaughterhouse',
#   'index': 61,
#   'total': 4415,
#   'text': 'I was a writer on Cape Cod.'},
#  {'title': 'slaughterhouse',
#   'index': 62,
#   'total': 4415,
#   'text': 'We had been privates in the war, infantry scouts.'},
#  {'title': 'slaughterhouse',
#   'index': 63,
#   'total': 4415,
#   'text': 'We had never expected to make any money after the war, but we were doing quite well.'},
#  {'title': 'slaughterhouse',
#   'index': 64,
#   'total': 4415,
#   'text': 'I had the Bell Telephone Company find him for me.'},
#  {'title': 'slaughterhouse',
#   'index': 65,
#   'total': 4415,
#   'text': 'They are wonderful that way.'},
#  {'title': 'slaughterhouse',
#   'index': 66,
#   'total': 4415,
#   'text': 'I have this, disease late at night sometimes, involving alcohol and the telephone.'},
#  {'title': 'slaughterhouse',
#   'index': 67,
#   'total': 4415,
#   'text': 'I get drunk, and I drive my wife away with a breath like mustard gas and roses.'},
#  {'title': 'slaughterhouse',
#   'index': 68,
#   'total': 4415,
#   'text': 'And then, speaking gravely and elegantly into the telephone, I ask the telephone operators to connect me with this friend or that one, from whom I have not heard in years.'},
#  {'title': 'slaughterhouse',
#   'index': 69,
#   'total': 4415,
#   'text': "I got O'Hare on the line in this way."},
#  {'title': 'slaughterhouse',
#   'index': 70,
#   'total': 4415,
#   'text': 'He is short and I am tall.'},
#  {'title': 'slaughterhouse',
#   'index': 71,
#   'total': 4415,
#   'text': 'We were Mutt and Jeff in the war.'},
#  {'title': 'slaughterhouse',
#   'index': 72,
#   'total': 4415,
#   'text': 'We were captured together in the war.'},
#  {'title': 'slaughterhouse',
#   'index': 73,
#   'total': 4415,
#   'text': 'I told him who I was on the telephone.'},
#  {'title': 'slaughterhouse',
#   'index': 74,
#   'total': 4415,
#   'text': 'He had no trouble believing it.'},
#  {'title': 'slaughterhouse', 'index': 75, 'total': 4415, 'text': 'He was up.'},
#  {'title': 'slaughterhouse',
#   'index': 76,
#   'total': 4415,
#   'text': 'He was reading.'},
#  {'title': 'slaughterhouse',
#   'index': 77,
#   'total': 4415,
#   'text': "Everybody else in his house was asleep. '"},
#  {'title': 'slaughterhouse',
#   'index': 78,
#   'total': 4415,
#   'text': "Listen,' I said, 'I'm writing this book about Dresden."},
#  {'title': 'slaughterhouse',
#   'index': 79,
#   'total': 4415,
#   'text': 'I’d like some help remembering stuff.'},
#  {'title': 'slaughterhouse',
#   'index': 80,
#   'total': 4415,
#   'text': "I wonder if I could come down and see you, and we could drink and talk and remember.'"},
#  {'title': 'slaughterhouse',
#   'index': 81,
#   'total': 4415,
#   'text': 'He was unenthusiastic.'},
#  {'title': 'slaughterhouse',
#   'index': 82,
#   'total': 4415,
#   'text': 'He said he couldn’t remember much.'},
#  {'title': 'slaughterhouse',
#   'index': 83,
#   'total': 4415,
#   'text': "He told me, though, to come ahead. '"},
#  {'title': 'slaughterhouse',
#   'index': 84,
#   'total': 4415,
#   'text': "I think the climax of the book will be the execution of poor old Edgar Derby,’ I said. '"},
#  {'title': 'slaughterhouse',
#   'index': 85,
#   'total': 4415,
#   'text': 'The irony is so great.'},
#  {'title': 'slaughterhouse',
#   'index': 86,
#   'total': 4415,
#   'text': 'A whole city gets burned down, and thousands and thousands of people are killed.'},
#  {'title': 'slaughterhouse',
#   'index': 87,
#   'total': 4415,
#   'text': 'And then this one American foot soldier is arrested in the ruins for taking a teapot.'},
#  {'title': 'slaughterhouse',
#   'index': 88,
#   'total': 4415,
#   'text': "And he’s given a regular trial, and then he's shot by a firing squad.'"},
#  {'title': 'slaughterhouse', 'index': 89, 'total': 4415, 'text': "'"},
#  {'title': 'slaughterhouse',
#   'index': 90,
#   'total': 4415,
#   'text': "Urn,' said O'Hare. '"},
#  {'title': 'slaughterhouse',
#   'index': 91,
#   'total': 4415,
#   'text': "Don't you think that's really where the climax should come?'"},
#  {'title': 'slaughterhouse', 'index': 92, 'total': 4415, 'text': "'"},
#  {'title': 'slaughterhouse',
#   'index': 93,
#   'total': 4415,
#   'text': "I don’t know anything about it,' he said. '"},
#  {'title': 'slaughterhouse',
#   'index': 94,
#   'total': 4415,
#   'text': "That's your trade, not mine.'"},
#  {'title': 'slaughterhouse',
#   'index': 95,
#   'total': 4415,
#   'text': 'As a trafficker in climaxes and thrills and characterization and wonderful dialogue and suspense and confrontations, I had outlined the Dresden story many times.'},
#  {'title': 'slaughterhouse',
#   'index': 96,
#   'total': 4415,
#   'text': 'The best outline I ever made, or anyway the prettiest one, was on the back of a roll of wallpaper.'},
#  {'title': 'slaughterhouse',
#   'index': 97,
#   'total': 4415,
#   'text': 'I used my daughter’s crayons, a different color for each main character.'},
#  {'title': 'slaughterhouse',
#   'index': 98,
#   'total': 4415,
#   'text': 'One end of the wallpaper was the beginning of the story, and the other end was the end, and then there was all that middle part, which was the middle.'},
#  {'title': 'slaughterhouse',
#   'index': 99,
#   'total': 4415,
#   'text': 'And the blue line met the red line and then the yellow line, and the yellow line stopped because the character represented by the yellow line was dead.'},
#  {'title': 'slaughterhouse',
#   'index': 100,
#   'total': 4415,
#   'text': 'And so on.'},
#  {'title': 'slaughterhouse',
#   'index': 101,
#   'total': 4415,
#   'text': 'The destruction of Dresden was represented by a vertical band of orange cross-hatching, and all the lines that were still alive passed through it, came out the other side.'},
#  {'title': 'slaughterhouse',
#   'index': 102,
#   'total': 4415,
#   'text': 'The end, where all the lines stopped, was a beeffield on the Elbe, outside of Halle.'},
#  {'title': 'slaughterhouse',
#   'index': 103,
#   'total': 4415,
#   'text': 'The rain was coming down.'},
#  {'title': 'slaughterhouse',
#   'index': 104,
#   'total': 4415,
#   'text': 'The war in Europe had been over for a couple of weeks.'},
#  {'title': 'slaughterhouse',
#   'index': 105,
#   'total': 4415,
#   'text': 'We were formed in ranks, with Russian soldiers guarding us-Englishmen, Americans, Dutchmen, Belgians, Frenchmen, Canadians, South Africans, New Zealanders, Australians, thousands of us about to stop being prisoners of war.'},
#  {'title': 'slaughterhouse',
#   'index': 106,
#   'total': 4415,
#   'text': 'And on the other side of the field were thousands of Russians and Poles and Yugoslavians and so on guarded by American soldiers.'},
#  {'title': 'slaughterhouse',
#   'index': 107,
#   'total': 4415,
#   'text': 'An exchange was made there in the rain-one for one.'},
#  {'title': 'slaughterhouse',
#   'index': 108,
#   'total': 4415,
#   'text': "O'Hare and I climbed into the back of an American truck with a lot of others."},
#  {'title': 'slaughterhouse',
#   'index': 109,
#   'total': 4415,
#   'text': "O'Hare didn’t have any souvenirs."},
#  {'title': 'slaughterhouse',
#   'index': 110,
#   'total': 4415,
#   'text': 'Almost everybody else did.'},
#  {'title': 'slaughterhouse',
#   'index': 111,
#   'total': 4415,
#   'text': 'I had a ceremonial Luftwaffe saber, still do.'},
#  {'title': 'slaughterhouse',
#   'index': 112,
#   'total': 4415,
#   'text': 'The rabid little American I call Paul Lazzaro in this book'},
#  {'title': 'slaughterhouse',
#   'index': 113,
#   'total': 4415,
#   'text': 'had about a quart of diamonds and emeralds and rubies and'},
#  {'title': 'slaughterhouse', 'index': 114, 'total': 4415, 'text': 'so on’'},
#  {'title': 'slaughterhouse',
#   'index': 115,
#   'total': 4415,
#   'text': 'He had taken these from dead people in the cellars of Dresden.'},
#  {'title': 'slaughterhouse', 'index': 116, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 117,
#   'total': 4415,
#   'text': 'So it goes.'},
#  {'title': 'slaughterhouse',
#   'index': 118,
#   'total': 4415,
#   'text': 'An idiotic Englishman, who had lost all his teeth somewhere had his souvenir in a canvas bag.'},
#  {'title': 'slaughterhouse',
#   'index': 119,
#   'total': 4415,
#   'text': 'The bag was resting on my insteps.'},
#  {'title': 'slaughterhouse',
#   'index': 120,
#   'total': 4415,
#   'text': 'He would peek into the bag every now and then, and he would roll his eyes and swivel his scrawny neck,, trying to catch people looking covetously at his bag.'},
#  {'title': 'slaughterhouse',
#   'index': 121,
#   'total': 4415,
#   'text': 'And he would bounce the bag on my insteps.'},
#  {'title': 'slaughterhouse',
#   'index': 122,
#   'total': 4415,
#   'text': 'I thought this bouncing was accidental.'},
#  {'title': 'slaughterhouse',
#   'index': 123,
#   'total': 4415,
#   'text': 'But I was mistaken.'},
#  {'title': 'slaughterhouse',
#   'index': 124,
#   'total': 4415,
#   'text': 'He had to show somebody what was in the bag, and he had decided he could trust me.'},
#  {'title': 'slaughterhouse',
#   'index': 125,
#   'total': 4415,
#   'text': 'He caught my eye, winked, opened the bag.'},
#  {'title': 'slaughterhouse',
#   'index': 126,
#   'total': 4415,
#   'text': 'There was a plaster model of the Eiffel Tower in there.'},
#  {'title': 'slaughterhouse',
#   'index': 127,
#   'total': 4415,
#   'text': 'It was painted gold.'},
#  {'title': 'slaughterhouse',
#   'index': 128,
#   'total': 4415,
#   'text': "It had a clock in it. '"},
#  {'title': 'slaughterhouse',
#   'index': 129,
#   'total': 4415,
#   'text': "There's a smashin’ thing,' he said."},
#  {'title': 'slaughterhouse',
#   'index': 130,
#   'total': 4415,
#   'text': 'And we were flown to a rest camp in France, where we were fed chocolate malted milkshakes and other rich foods until we were all covered with baby fat.'},
#  {'title': 'slaughterhouse',
#   'index': 131,
#   'total': 4415,
#   'text': 'Then we were sent home, and I married a pretty girl who was covered with baby fat, too.'},
#  {'title': 'slaughterhouse',
#   'index': 132,
#   'total': 4415,
#   'text': 'And we had babies.'},
#  {'title': 'slaughterhouse',
#   'index': 133,
#   'total': 4415,
#   'text': "And they're all grown up now, and I'm an old fart with his memories and his Pall Malls."},
#  {'title': 'slaughterhouse',
#   'index': 134,
#   'total': 4415,
#   'text': 'My name is Yon Yonson, I work in Wisconsin, I work in a lumbermill there.'},
#  {'title': 'slaughterhouse',
#   'index': 135,
#   'total': 4415,
#   'text': "Sometimes I try to call up old girl friends on the telephone late at night, after my wife has gone to bed. '"},
#  {'title': 'slaughterhouse',
#   'index': 136,
#   'total': 4415,
#   'text': 'Operator, I wonder if you could give me the number of a Mrs. So-and-'},
#  {'title': 'slaughterhouse', 'index': 137, 'total': 4415, 'text': 'So.'},
#  {'title': 'slaughterhouse',
#   'index': 138,
#   'total': 4415,
#   'text': 'I think she lives at such-and-such.'},
#  {'title': 'slaughterhouse', 'index': 139, 'total': 4415, 'text': "’ '"},
#  {'title': 'slaughterhouse',
#   'index': 140,
#   'total': 4415,
#   'text': "I'm sorry, sir."},
#  {'title': 'slaughterhouse',
#   'index': 141,
#   'total': 4415,
#   'text': "There is no such listing.' '"},
#  {'title': 'slaughterhouse',
#   'index': 142,
#   'total': 4415,
#   'text': 'Thanks, Operator.'},
#  {'title': 'slaughterhouse',
#   'index': 143,
#   'total': 4415,
#   'text': 'Thanks just the same.'},
#  {'title': 'slaughterhouse', 'index': 144, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 145,
#   'total': 4415,
#   'text': 'And I let the dog out'},
#  {'title': 'slaughterhouse',
#   'index': 146,
#   'total': 4415,
#   'text': 'or I let him in, and we talk some.'},
#  {'title': 'slaughterhouse',
#   'index': 147,
#   'total': 4415,
#   'text': 'I let him know I like him, and he lets me know he likes me.'},
#  {'title': 'slaughterhouse',
#   'index': 148,
#   'total': 4415,
#   'text': "He doesn't mind the smell of mustard gas and roses. '"},
#  {'title': 'slaughterhouse',
#   'index': 149,
#   'total': 4415,
#   'text': "You're all right,"},
#  {'title': 'slaughterhouse',
#   'index': 150,
#   'total': 4415,
#   'text': "Sandy, I’ll say to the dog. '"},
#  {'title': 'slaughterhouse',
#   'index': 151,
#   'total': 4415,
#   'text': 'You know that, Sandy?'},
#  {'title': 'slaughterhouse', 'index': 152, 'total': 4415, 'text': "You're"},
#  {'title': 'slaughterhouse', 'index': 153, 'total': 4415, 'text': "O.K.'"},
#  {'title': 'slaughterhouse',
#   'index': 154,
#   'total': 4415,
#   'text': "Sometimes I'll turn on the radio and listen to a talk program from Boston or New York."},
#  {'title': 'slaughterhouse',
#   'index': 155,
#   'total': 4415,
#   'text': 'I can’t stand recorded music if I’ve been drinking a good deal.'},
#  {'title': 'slaughterhouse',
#   'index': 156,
#   'total': 4415,
#   'text': 'Sooner or later I go to bed, and my wife asks me what time it is.'},
#  {'title': 'slaughterhouse',
#   'index': 157,
#   'total': 4415,
#   'text': 'She always has to know the time.'},
#  {'title': 'slaughterhouse',
#   'index': 158,
#   'total': 4415,
#   'text': "Sometimes I don’t know, and I say, ’Search me.'"},
#  {'title': 'slaughterhouse',
#   'index': 159,
#   'total': 4415,
#   'text': 'I think about my education sometimes.'},
#  {'title': 'slaughterhouse',
#   'index': 160,
#   'total': 4415,
#   'text': 'I went to the University of Chicago for a while after the Second World War.'},
#  {'title': 'slaughterhouse',
#   'index': 161,
#   'total': 4415,
#   'text': 'I was a student in the Department of Anthropology.'},
#  {'title': 'slaughterhouse',
#   'index': 162,
#   'total': 4415,
#   'text': 'At that time, they were teaching that there was absolutely no difference between anybody.'},
#  {'title': 'slaughterhouse',
#   'index': 163,
#   'total': 4415,
#   'text': 'They may be teaching that still.'},
#  {'title': 'slaughterhouse',
#   'index': 164,
#   'total': 4415,
#   'text': 'Another thing they taught was that nobody was ridiculous or bad or disgusting.'},
#  {'title': 'slaughterhouse',
#   'index': 165,
#   'total': 4415,
#   'text': 'Shortly before my father died, he said to me, ’You know-you never wrote a story with a villain in it.'},
#  {'title': 'slaughterhouse', 'index': 166, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 167,
#   'total': 4415,
#   'text': 'I told him that was one of the things I learned in college after the war.'},
#  {'title': 'slaughterhouse',
#   'index': 168,
#   'total': 4415,
#   'text': 'While I was studying to be an anthropologist, I was also working as a police reporter for the famous Chicago City News Bureau for twenty-eight dollars a week.'},
#  {'title': 'slaughterhouse',
#   'index': 169,
#   'total': 4415,
#   'text': 'One time they switched me from the night shift to the day shift.'},
#  {'title': 'slaughterhouse',
#   'index': 170,
#   'total': 4415,
#   'text': ', so I worked sixteen hours straight.'},
#  {'title': 'slaughterhouse',
#   'index': 171,
#   'total': 4415,
#   'text': 'We were supported by all the newspapers in town, and the AP and the UP and all that.'},
#  {'title': 'slaughterhouse',
#   'index': 172,
#   'total': 4415,
#   'text': 'And we would cover the courts and the police stations and the Fire Department and the Coast Guard out on Lake Michigan and all that.'},
#  {'title': 'slaughterhouse',
#   'index': 173,
#   'total': 4415,
#   'text': 'We were connected to the institutions that supported us by means of pneumatic tubes which ran under the streets of Chicago.'},
#  {'title': 'slaughterhouse',
#   'index': 174,
#   'total': 4415,
#   'text': 'Reporters would telephone in stories to writers wearing headphones, and the writers would stencil the stories on mimeograph sheets.'},
#  {'title': 'slaughterhouse',
#   'index': 175,
#   'total': 4415,
#   'text': 'The stories were mimeographed and stuffed into the brass and velvet cartridges which the pneumatic tubes ate.'},
#  {'title': 'slaughterhouse',
#   'index': 176,
#   'total': 4415,
#   'text': 'The very toughest reporters and writers were women who had taken over the jobs of men who’d gone to war.'},
#  {'title': 'slaughterhouse',
#   'index': 177,
#   'total': 4415,
#   'text': 'And the first story I covered I had to dictate over the telephone to one of those beastly girls.'},
#  {'title': 'slaughterhouse',
#   'index': 178,
#   'total': 4415,
#   'text': 'It was about a young veteran who had taken a job running an old-fashioned elevator in an office building.'},
#  {'title': 'slaughterhouse',
#   'index': 179,
#   'total': 4415,
#   'text': 'The elevator door on the first floor was ornamental iron lace.'},
#  {'title': 'slaughterhouse',
#   'index': 180,
#   'total': 4415,
#   'text': 'Iron ivy snaked in and out of the holes.'},
#  {'title': 'slaughterhouse',
#   'index': 181,
#   'total': 4415,
#   'text': 'There was an iron twig with two iron lovebirds perched upon it.'},
#  {'title': 'slaughterhouse',
#   'index': 182,
#   'total': 4415,
#   'text': 'This veteran decided to take his car into the basement, and he closed the door and started down, but his wedding ring Was caught in all the ornaments.'},
#  {'title': 'slaughterhouse',
#   'index': 183,
#   'total': 4415,
#   'text': 'So he was hoisted into the air and the floor of the car went down, dropped out from under him, and the top of the car squashed him.'},
#  {'title': 'slaughterhouse',
#   'index': 184,
#   'total': 4415,
#   'text': 'So it goes.'},
#  {'title': 'slaughterhouse',
#   'index': 185,
#   'total': 4415,
#   'text': 'So I phoned this in, and the woman who was going to cut the stencil asked me.'},
#  {'title': 'slaughterhouse', 'index': 186, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 187,
#   'total': 4415,
#   'text': 'What did his wife say?'},
#  {'title': 'slaughterhouse', 'index': 188, 'total': 4415, 'text': '’ ’'},
#  {'title': 'slaughterhouse',
#   'index': 189,
#   'total': 4415,
#   'text': 'She doesn’t know yet,’ I said.'},
#  {'title': 'slaughterhouse', 'index': 190, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 191,
#   'total': 4415,
#   'text': 'It just happened.'},
#  {'title': 'slaughterhouse',
#   'index': 192,
#   'total': 4415,
#   'text': '’ ’Call her up and get a statement.'},
#  {'title': 'slaughterhouse', 'index': 193, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse', 'index': 194, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse', 'index': 195, 'total': 4415, 'text': 'What?'},
#  {'title': 'slaughterhouse',
#   'index': 196,
#   'total': 4415,
#   'text': "’ ’Tell her you're Captain Finn of the Police Department."},
#  {'title': 'slaughterhouse',
#   'index': 197,
#   'total': 4415,
#   'text': 'Say you have some sad news.'},
#  {'title': 'slaughterhouse',
#   'index': 198,
#   'total': 4415,
#   'text': "Give her the news, and see what she says.'"},
#  {'title': 'slaughterhouse', 'index': 199, 'total': 4415, 'text': 'So I did.'},
#  {'title': 'slaughterhouse',
#   'index': 200,
#   'total': 4415,
#   'text': 'She said about what you would expect her to say.'},
#  {'title': 'slaughterhouse',
#   'index': 201,
#   'total': 4415,
#   'text': 'There was a baby.'},
#  {'title': 'slaughterhouse',
#   'index': 202,
#   'total': 4415,
#   'text': 'And so on.'},
#  {'title': 'slaughterhouse',
#   'index': 203,
#   'total': 4415,
#   'text': 'When I got back to the office, the woman writer asked me, just for her own information, what the squashed guy had looked Eke when he was squashed.'},
#  {'title': 'slaughterhouse',
#   'index': 204,
#   'total': 4415,
#   'text': "I told her. '"},
#  {'title': 'slaughterhouse',
#   'index': 205,
#   'total': 4415,
#   'text': "Did it bother you?'"},
#  {'title': 'slaughterhouse', 'index': 206, 'total': 4415, 'text': 'she said.'},
#  {'title': 'slaughterhouse',
#   'index': 207,
#   'total': 4415,
#   'text': "She was eating a Three Musketeers Candy Bar. '"},
#  {'title': 'slaughterhouse',
#   'index': 208,
#   'total': 4415,
#   'text': "Heck no, Nancy,' I said. '"},
#  {'title': 'slaughterhouse',
#   'index': 209,
#   'total': 4415,
#   'text': "I’ve seen lots worse than that in the war.'"},
#  {'title': 'slaughterhouse',
#   'index': 210,
#   'total': 4415,
#   'text': 'Even then I was supposedly writing a book about Dresden.'},
#  {'title': 'slaughterhouse',
#   'index': 211,
#   'total': 4415,
#   'text': 'It wasn’t a famous air raid back then in America.'},
#  {'title': 'slaughterhouse',
#   'index': 212,
#   'total': 4415,
#   'text': 'Not many Americans knew how much worse it had been than Hiroshima, for instance.'},
#  {'title': 'slaughterhouse',
#   'index': 213,
#   'total': 4415,
#   'text': 'I didn’t know that, either.'},
#  {'title': 'slaughterhouse',
#   'index': 214,
#   'total': 4415,
#   'text': 'There hadn’t been much publicity.'},
#  {'title': 'slaughterhouse',
#   'index': 215,
#   'total': 4415,
#   'text': 'I happened to tell a University of Chicago professor at a cocktail party about the raid as I had seen it, about the book I would write.'},
#  {'title': 'slaughterhouse',
#   'index': 216,
#   'total': 4415,
#   'text': 'He was a member of a thing called The Committee on Social Thought.'},
#  {'title': 'slaughterhouse',
#   'index': 217,
#   'total': 4415,
#   'text': 'And he told me about the concentration camps, and about how the Germans had made soap and candles out of the fat of dead Jews and so on.'},
#  {'title': 'slaughterhouse',
#   'index': 218,
#   'total': 4415,
#   'text': "All could say was, 'I know, I know."},
#  {'title': 'slaughterhouse', 'index': 219, 'total': 4415, 'text': 'I know.'},
#  {'title': 'slaughterhouse', 'index': 220, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 221,
#   'total': 4415,
#   'text': 'The Second World War had certainly made everybody very tough.'},
#  {'title': 'slaughterhouse',
#   'index': 222,
#   'total': 4415,
#   'text': 'And I became a public relations man for General Electric in Schenectady, New York, and a volunteer fireman in the Village of Alplaus, where I bought my first home.'},
#  {'title': 'slaughterhouse',
#   'index': 223,
#   'total': 4415,
#   'text': 'My boss there was one of the toughest guys I ever hope to meet.'},
#  {'title': 'slaughterhouse',
#   'index': 224,
#   'total': 4415,
#   'text': 'He had been a lieutenant colonel in public relations in Baltimore.'},
#  {'title': 'slaughterhouse',
#   'index': 225,
#   'total': 4415,
#   'text': 'While I was in Schenectady he joined the Dutch Refonned Church, which is a very tough church, indeed.'},
#  {'title': 'slaughterhouse',
#   'index': 226,
#   'total': 4415,
#   'text': "He used to ask me sneeringly sometimes why I hadn’t been an officer, as though I'd done something wrong."},
#  {'title': 'slaughterhouse',
#   'index': 227,
#   'total': 4415,
#   'text': 'My wife and I had lost our baby fat.'},
#  {'title': 'slaughterhouse',
#   'index': 228,
#   'total': 4415,
#   'text': 'Those were our scrawny years.'},
#  {'title': 'slaughterhouse',
#   'index': 229,
#   'total': 4415,
#   'text': 'We had a lot of scrawny veterans and their scrawny wives for friends.'},
#  {'title': 'slaughterhouse',
#   'index': 230,
#   'total': 4415,
#   'text': 'The nicest veterans in Schenectady, I thought, the kindest and funniest ones, the ones who hated war the most, were the ones who’d really fought.'},
#  {'title': 'slaughterhouse',
#   'index': 231,
#   'total': 4415,
#   'text': 'I wrote the Air Force back then, asking for details about the raid on Dresden, who ordered it, how many planes did it, why they did it, what desirable results there had been and so on.'},
#  {'title': 'slaughterhouse',
#   'index': 232,
#   'total': 4415,
#   'text': 'I was answered by a man who, like myself, was in public relations.'},
#  {'title': 'slaughterhouse',
#   'index': 233,
#   'total': 4415,
#   'text': 'He said that he was sorry, but that the infonnation was top secret still.'},
#  {'title': 'slaughterhouse',
#   'index': 234,
#   'total': 4415,
#   'text': "I read the letter out loud to my wife, and I said, 'Secret?"},
#  {'title': 'slaughterhouse',
#   'index': 235,
#   'total': 4415,
#   'text': "My God-from whom?'"},
#  {'title': 'slaughterhouse',
#   'index': 236,
#   'total': 4415,
#   'text': 'We were United World Federalists back then.'},
#  {'title': 'slaughterhouse',
#   'index': 237,
#   'total': 4415,
#   'text': 'I don’t know what we are now.'},
#  {'title': 'slaughterhouse',
#   'index': 238,
#   'total': 4415,
#   'text': 'Telephoners, I guess.'},
#  {'title': 'slaughterhouse',
#   'index': 239,
#   'total': 4415,
#   'text': 'We telephone a lot-or /do, anyway, late at night.'},
#  {'title': 'slaughterhouse',
#   'index': 240,
#   'total': 4415,
#   'text': "A couple of weeks after I telephoned my old war buddy, Bernard V. O'Hare, I really did go to see him."},
#  {'title': 'slaughterhouse',
#   'index': 241,
#   'total': 4415,
#   'text': "That must have been in 1964 or so-whatever the last year was for the New York World's Fair."},
#  {'title': 'slaughterhouse',
#   'index': 242,
#   'total': 4415,
#   'text': 'Eheu, fugaces labuntur anni.'},
#  {'title': 'slaughterhouse',
#   'index': 243,
#   'total': 4415,
#   'text': 'My name is Yon Yonson.'},
#  {'title': 'slaughterhouse',
#   'index': 244,
#   'total': 4415,
#   'text': 'There was a young man from Stamboul.'},
#  {'title': 'slaughterhouse',
#   'index': 245,
#   'total': 4415,
#   'text': 'I took two little girls with me, my daughter, Nanny, and her best friend, Allison Mitchell.'},
#  {'title': 'slaughterhouse',
#   'index': 246,
#   'total': 4415,
#   'text': 'They had never been off Cape Cod before.'},
#  {'title': 'slaughterhouse',
#   'index': 247,
#   'total': 4415,
#   'text': 'When we saw a river, we had to stop so they could stand by it and think about it for a while.'},
#  {'title': 'slaughterhouse',
#   'index': 248,
#   'total': 4415,
#   'text': 'They had never seen water in that long and narrow, unsalted form before.'},
#  {'title': 'slaughterhouse',
#   'index': 249,
#   'total': 4415,
#   'text': 'The river was the Hudson.'},
#  {'title': 'slaughterhouse',
#   'index': 250,
#   'total': 4415,
#   'text': 'There were carp in there and we saw them.'},
#  {'title': 'slaughterhouse',
#   'index': 251,
#   'total': 4415,
#   'text': 'They were as big as atomic submarines.'},
#  {'title': 'slaughterhouse',
#   'index': 252,
#   'total': 4415,
#   'text': 'We saw waterfalls, too, streams jumping off cliffs into the valley of the Delaware.'},
#  {'title': 'slaughterhouse',
#   'index': 253,
#   'total': 4415,
#   'text': 'There were lots of things to stop and see-and then it was time to go, always time to go.'},
#  {'title': 'slaughterhouse',
#   'index': 254,
#   'total': 4415,
#   'text': 'The little girls were wearing white party dresses and black party shoes, so strangers would know at once how nice they were.'},
#  {'title': 'slaughterhouse',
#   'index': 255,
#   'total': 4415,
#   'text': '’Time to go, girls,’ I’d say.'},
#  {'title': 'slaughterhouse',
#   'index': 256,
#   'total': 4415,
#   'text': 'And we would go.'},
#  {'title': 'slaughterhouse',
#   'index': 257,
#   'total': 4415,
#   'text': "And the sun went down, and we had supper in an Italian place, and then I knocked on the front door of the beautiful stone house of Bernard V. O'Hare."},
#  {'title': 'slaughterhouse',
#   'index': 258,
#   'total': 4415,
#   'text': 'I was carrying a bottle of Irish whiskey like a dinner bell.'},
#  {'title': 'slaughterhouse',
#   'index': 259,
#   'total': 4415,
#   'text': 'I met his nice wife, Mary, to whom I dedicate this book.'},
#  {'title': 'slaughterhouse',
#   'index': 260,
#   'total': 4415,
#   'text': 'I dedicate it to Gerhard Muller, the Dresden taxi driver, too.'},
#  {'title': 'slaughterhouse',
#   'index': 261,
#   'total': 4415,
#   'text': "Mary O'Hare is a trained nurse, which is a lovely thing for a woman to be."},
#  {'title': 'slaughterhouse',
#   'index': 262,
#   'total': 4415,
#   'text': 'Mary admired the two little girls I’d brought, mixed them in with her own children, sent them all upstairs to play games and watch television.'},
#  {'title': 'slaughterhouse',
#   'index': 263,
#   'total': 4415,
#   'text': 'It was only after the children were gone that I sensed that Mary didn’t like me or didn’t like something about the night.'},
#  {'title': 'slaughterhouse',
#   'index': 264,
#   'total': 4415,
#   'text': 'She was polite but chilly.'},
#  {'title': 'slaughterhouse', 'index': 265, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 266,
#   'total': 4415,
#   'text': "It's a nice cozy house you have here,' I said, and it really was. '"},
#  {'title': 'slaughterhouse',
#   'index': 267,
#   'total': 4415,
#   'text': "I've fixed up a place where you can talk and not be bothered,' she said. '"},
#  {'title': 'slaughterhouse',
#   'index': 268,
#   'total': 4415,
#   'text': "Good,' I said, and I imagined two leather chairs near a fire in a paneled room, where two old soldiers could drink and talk."},
#  {'title': 'slaughterhouse',
#   'index': 269,
#   'total': 4415,
#   'text': 'But she took us into the kitchen.'},
#  {'title': 'slaughterhouse',
#   'index': 270,
#   'total': 4415,
#   'text': 'She had put two straight-backed chairs at a kitchen table with a white porcelain top.'},
#  {'title': 'slaughterhouse',
#   'index': 271,
#   'total': 4415,
#   'text': 'That table top was screaming with reflected light from a two-hundred-watt bulb overhead.'},
#  {'title': 'slaughterhouse',
#   'index': 272,
#   'total': 4415,
#   'text': 'Mary had prepared an operating room.'},
#  {'title': 'slaughterhouse',
#   'index': 273,
#   'total': 4415,
#   'text': 'She put only one glass on it, which was for me.'},
#  {'title': 'slaughterhouse',
#   'index': 274,
#   'total': 4415,
#   'text': "She explained that O'Hare couldn’t drink the hard stuff since the war."},
#  {'title': 'slaughterhouse',
#   'index': 275,
#   'total': 4415,
#   'text': 'So we sat down.'},
#  {'title': 'slaughterhouse',
#   'index': 276,
#   'total': 4415,
#   'text': "O'Hare was embarrassed, but he wouldn't tell me what was wrong."},
#  {'title': 'slaughterhouse',
#   'index': 277,
#   'total': 4415,
#   'text': 'I couldn’t imagine what it was about me that could bum up Mary so.'},
#  {'title': 'slaughterhouse',
#   'index': 278,
#   'total': 4415,
#   'text': 'I was a family man.'},
#  {'title': 'slaughterhouse',
#   'index': 279,
#   'total': 4415,
#   'text': 'I’d been married only once.'},
#  {'title': 'slaughterhouse',
#   'index': 280,
#   'total': 4415,
#   'text': 'I wasn’t a drunk.'},
#  {'title': 'slaughterhouse',
#   'index': 281,
#   'total': 4415,
#   'text': 'I hadn’t done her husband any dirt in the war.'},
#  {'title': 'slaughterhouse',
#   'index': 282,
#   'total': 4415,
#   'text': 'She fixed herself a Coca-Cola, made a lot of noise banging the ice-cube tray in the stainless steel sink.'},
#  {'title': 'slaughterhouse',
#   'index': 283,
#   'total': 4415,
#   'text': 'Then she went into another part of the house.'},
#  {'title': 'slaughterhouse',
#   'index': 284,
#   'total': 4415,
#   'text': 'But she wouldn’t sit still.'},
#  {'title': 'slaughterhouse',
#   'index': 285,
#   'total': 4415,
#   'text': 'She was moving all over the house, opening and shutting doors, even moving furniture around to work off anger.'},
#  {'title': 'slaughterhouse',
#   'index': 286,
#   'total': 4415,
#   'text': "I asked O’Hare what I’d said or done to make her act that way. '"},
#  {'title': 'slaughterhouse',
#   'index': 287,
#   'total': 4415,
#   'text': "It's all right,' he said."},
#  {'title': 'slaughterhouse', 'index': 288, 'total': 4415, 'text': '"'},
#  {'title': 'slaughterhouse',
#   'index': 289,
#   'total': 4415,
#   'text': 'Don’t worry about it.'},
#  {'title': 'slaughterhouse',
#   'index': 290,
#   'total': 4415,
#   'text': 'It doesn’t have anything to do with you.'},
#  {'title': 'slaughterhouse', 'index': 291, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 292,
#   'total': 4415,
#   'text': 'That was kind of him.'},
#  {'title': 'slaughterhouse',
#   'index': 293,
#   'total': 4415,
#   'text': 'He was lying.'},
#  {'title': 'slaughterhouse',
#   'index': 294,
#   'total': 4415,
#   'text': 'It had everything to do with me.'},
#  {'title': 'slaughterhouse',
#   'index': 295,
#   'total': 4415,
#   'text': 'So we tried to ignore Mary and remember the war.'},
#  {'title': 'slaughterhouse',
#   'index': 296,
#   'total': 4415,
#   'text': "I took a couple of belts of the booze I'd brought."},
#  {'title': 'slaughterhouse',
#   'index': 297,
#   'total': 4415,
#   'text': 'We would chuckle or grin sometimes, as though war stories were coming back, but neither one of us could remember anything good.'},
#  {'title': 'slaughterhouse',
#   'index': 298,
#   'total': 4415,
#   'text': "O'Hare remembered one guy who got into a lot of wine in Dresden, before it was bombed, and we had to take him home in a wheelbarrow."},
#  {'title': 'slaughterhouse',
#   'index': 299,
#   'total': 4415,
#   'text': 'It wasn’t much to write a book about.'},
#  {'title': 'slaughterhouse',
#   'index': 300,
#   'total': 4415,
#   'text': 'I remembered two Russian soldiers who had looted a clock factory.'},
#  {'title': 'slaughterhouse',
#   'index': 301,
#   'total': 4415,
#   'text': 'They had a horse-drawn wagon full of clocks.'},
#  {'title': 'slaughterhouse',
#   'index': 302,
#   'total': 4415,
#   'text': 'They were happy and drunk.'},
#  {'title': 'slaughterhouse',
#   'index': 303,
#   'total': 4415,
#   'text': 'They were smoking huge cigarettes they had rolled in newspaper.'},
#  {'title': 'slaughterhouse',
#   'index': 304,
#   'total': 4415,
#   'text': 'That was about it for memories, and Mary was still making noise.'},
#  {'title': 'slaughterhouse',
#   'index': 305,
#   'total': 4415,
#   'text': 'She finally came out in the kitchen again for another Coke.'},
#  {'title': 'slaughterhouse',
#   'index': 306,
#   'total': 4415,
#   'text': 'She took another tray of ice cubes from the refrigerator, banged it in the sink, even though there was already plenty of ice out.'},
#  {'title': 'slaughterhouse',
#   'index': 307,
#   'total': 4415,
#   'text': 'Then she turned to me, let me see how angry she was, and that the anger was for me.'},
#  {'title': 'slaughterhouse',
#   'index': 308,
#   'total': 4415,
#   'text': 'She had been talking to herself, so what she said was a fragment of a much larger conversation.'},
#  {'title': 'slaughterhouse', 'index': 309, 'total': 4415, 'text': '"'},
#  {'title': 'slaughterhouse',
#   'index': 310,
#   'total': 4415,
#   'text': "You were just babies then!'"},
#  {'title': 'slaughterhouse', 'index': 311, 'total': 4415, 'text': 'she said.'},
#  {'title': 'slaughterhouse', 'index': 312, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse', 'index': 313, 'total': 4415, 'text': 'What?'},
#  {'title': 'slaughterhouse', 'index': 314, 'total': 4415, 'text': '"'},
#  {'title': 'slaughterhouse', 'index': 315, 'total': 4415, 'text': "I said. '"},
#  {'title': 'slaughterhouse',
#   'index': 316,
#   'total': 4415,
#   'text': "You were just babies in the war-like the ones upstairs! '"},
#  {'title': 'slaughterhouse',
#   'index': 317,
#   'total': 4415,
#   'text': 'I nodded that this was true.'},
#  {'title': 'slaughterhouse',
#   'index': 318,
#   'total': 4415,
#   'text': "We had been foolish virgins in the war, right at the end of childhood. '"},
#  {'title': 'slaughterhouse',
#   'index': 319,
#   'total': 4415,
#   'text': "But you're not going to write it that way, are you."},
#  {'title': 'slaughterhouse', 'index': 320, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 321,
#   'total': 4415,
#   'text': "This wasn't a question."},
#  {'title': 'slaughterhouse',
#   'index': 322,
#   'total': 4415,
#   'text': "It was an accusation. '"},
#  {'title': 'slaughterhouse',
#   'index': 323,
#   'total': 4415,
#   'text': "I-I don’t know,’ I said. '"},
#  {'title': 'slaughterhouse',
#   'index': 324,
#   'total': 4415,
#   'text': "Well, / know,' she said. '"},
#  {'title': 'slaughterhouse',
#   'index': 325,
#   'total': 4415,
#   'text': "You'll pretend you were men instead of babies, and you'll be played in the movies by Frank Sinatra and John Wayne or some of those other glamorous, war-loving, dirty old men."},
#  {'title': 'slaughterhouse',
#   'index': 326,
#   'total': 4415,
#   'text': "And war will look just wonderful, so we'll have a lot more of them."},
#  {'title': 'slaughterhouse',
#   'index': 327,
#   'total': 4415,
#   'text': "And they'll be fought by babies like the babies upstairs."},
#  {'title': 'slaughterhouse', 'index': 328, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 329,
#   'total': 4415,
#   'text': 'So then I understood.'},
#  {'title': 'slaughterhouse',
#   'index': 330,
#   'total': 4415,
#   'text': 'It was war that made her so angry.'},
#  {'title': 'slaughterhouse',
#   'index': 331,
#   'total': 4415,
#   'text': "She didn't want her babies or anybody else's babies killed in wars."},
#  {'title': 'slaughterhouse',
#   'index': 332,
#   'total': 4415,
#   'text': 'And she thought wars were partly encouraged by books and movies.'},
#  {'title': 'slaughterhouse',
#   'index': 333,
#   'total': 4415,
#   'text': "So I held up my right hand and I made her a promise '"},
#  {'title': 'slaughterhouse',
#   'index': 334,
#   'total': 4415,
#   'text': "Mary,' I said, 'I don’t think this book is ever going to be finished."},
#  {'title': 'slaughterhouse',
#   'index': 335,
#   'total': 4415,
#   'text': 'I must have written five thousand pages by now, and thrown them all away.'},
#  {'title': 'slaughterhouse',
#   'index': 336,
#   'total': 4415,
#   'text': "If I ever do finish it, though, I give you my word of honor: there won’t be a part for Fra nk Sinatra or John Wayne. '"},
#  {'title': 'slaughterhouse',
#   'index': 337,
#   'total': 4415,
#   'text': "I tell you what,' I said, 'I'll call it"},
#  {'title': 'slaughterhouse',
#   'index': 338,
#   'total': 4415,
#   'text': "The Children's Crusade.'"},
#  {'title': 'slaughterhouse',
#   'index': 339,
#   'total': 4415,
#   'text': 'She was my friend after that.'},
#  {'title': 'slaughterhouse', 'index': 340, 'total': 4415, 'text': "O'Hare"},
#  {'title': 'slaughterhouse',
#   'index': 341,
#   'total': 4415,
#   'text': 'and I gave up on remembering, went into the living room, talked about other things.'},
#  {'title': 'slaughterhouse',
#   'index': 342,
#   'total': 4415,
#   'text': "We became curious about the real Children's Crusade, so O'Hare looked it up in a book he had, Extraordinary Popular Delusions and the Madness of Crowds, by Charles Mackay,"},
#  {'title': 'slaughterhouse', 'index': 343, 'total': 4415, 'text': 'LL.D.'},
#  {'title': 'slaughterhouse',
#   'index': 344,
#   'total': 4415,
#   'text': 'It was first published in London in 1841.'},
#  {'title': 'slaughterhouse',
#   'index': 345,
#   'total': 4415,
#   'text': 'Mackay had a low opinion of all Crusades.'},
#  {'title': 'slaughterhouse',
#   'index': 346,
#   'total': 4415,
#   'text': "The Children's Crusade struck him as only slightly more sordid than the ten Crusades for grown-ups."},
#  {'title': 'slaughterhouse',
#   'index': 347,
#   'total': 4415,
#   'text': "O'Hare read this handsome passage out loud"},
#  {'title': 'slaughterhouse',
#   'index': 348,
#   'total': 4415,
#   'text': ': History in her solemn page informs us that the Crusaders were but ignorant and savage men, that their motives were those of bigotry unmitigated, and that their pathway was one of blood and wars.'},
#  {'title': 'slaughterhouse',
#   'index': 349,
#   'total': 4415,
#   'text': 'Romance, on the other hand, dilates upon their piety and heroism, and portrays, in her most glowing and impassioned hues, their virtue and magnanimity, the imperishable honor they acquired for themselves, and the great services they rendered to Christianity.'},
#  {'title': 'slaughterhouse',
#   'index': 350,
#   'total': 4415,
#   'text': "And then O'Hare read this: Now what was the grand result of all these struggles?"},
#  {'title': 'slaughterhouse',
#   'index': 351,
#   'total': 4415,
#   'text': 'Europe expended millions of her treasures, and the blood of two million of her people; and a handful of quarrelsome knights retained possession of Palestine for about one hundred years!'},
#  {'title': 'slaughterhouse',
#   'index': 352,
#   'total': 4415,
#   'text': "Mackay told us that the Children's Crusade started in 1213, when two monks got the idea of raising armies of children in Germany and France, and selling them in North Africa as slaves."},
#  {'title': 'slaughterhouse',
#   'index': 353,
#   'total': 4415,
#   'text': 'Thirty thousand children volunteered, thinking they were going to Palestine.'},
#  {'title': 'slaughterhouse',
#   'index': 354,
#   'total': 4415,
#   'text': 'They were no doubt idle and deserted children who generally swarm in great cities, nurtured on vice and daring, said Mackay, and ready for anything.'},
#  {'title': 'slaughterhouse',
#   'index': 355,
#   'total': 4415,
#   'text': "Pope Innocent the Third thought they were going to Palestine, too, and he was thrilled. '"},
#  {'title': 'slaughterhouse',
#   'index': 356,
#   'total': 4415,
# ...
#  {'title': 'slaughterhouse',
#   'index': 886,
#   'total': 4415,
#   'text': 'It was like an execution.'},
#  {'title': 'slaughterhouse',
#   'index': 887,
#   'total': 4415,
#   'text': 'Billy was numb as his father carried him from the shower room to the pool.'},
#  {'title': 'slaughterhouse',
#   'index': 888,
#   'total': 4415,
#   'text': 'His eyes were closed.'},
#  {'title': 'slaughterhouse',
#   'index': 889,
#   'total': 4415,
#   'text': 'When he opened his eyes, he was on the bottom of the pool, and there was beautiful music everywhere.'},
#  {'title': 'slaughterhouse',
#   'index': 890,
#   'total': 4415,
#   'text': 'He lost consciousness, but the music went on.'},
#  {'title': 'slaughterhouse',
#   'index': 891,
#   'total': 4415,
#   'text': 'He dimly sensed that somebody was rescuing him.'},
#  {'title': 'slaughterhouse',
#   'index': 892,
#   'total': 4415,
#   'text': 'Billy resented that.'},
#  {'title': 'slaughterhouse',
#   'index': 893,
#   'total': 4415,
#   'text': 'From there he traveled in time to 1965.'},
#  {'title': 'slaughterhouse',
#   'index': 894,
#   'total': 4415,
#   'text': "He was forty-one years old, and he was visiting his decrepit mother at Pine Knoll, an old people's home he had put her in only a month before."},
#  {'title': 'slaughterhouse',
#   'index': 895,
#   'total': 4415,
#   'text': 'She had caught pneumonia, and wasn’t expected to live.'},
#  {'title': 'slaughterhouse',
#   'index': 896,
#   'total': 4415,
#   'text': 'She did live, though, for years after that.'},
#  {'title': 'slaughterhouse',
#   'index': 897,
#   'total': 4415,
#   'text': 'Her voice was nearly gone, so, in order to hear her, Billy had to put his ear right next to her papery lips.'},
#  {'title': 'slaughterhouse',
#   'index': 898,
#   'total': 4415,
#   'text': "She evidently had something very important to say. '"},
#  {'title': 'slaughterhouse', 'index': 899, 'total': 4415, 'text': "How ...?'"},
#  {'title': 'slaughterhouse',
#   'index': 900,
#   'total': 4415,
#   'text': 'she began, and she stopped.'},
#  {'title': 'slaughterhouse',
#   'index': 901,
#   'total': 4415,
#   'text': 'She was too tired.'},
#  {'title': 'slaughterhouse',
#   'index': 902,
#   'total': 4415,
#   'text': 'She hoped that she wouldn’t have to say the rest of the sentence, and that Billy would finish it for her'},
#  {'title': 'slaughterhouse',
#   'index': 903,
#   'total': 4415,
#   'text': "But Billy had no idea what was on her mind. '"},
#  {'title': 'slaughterhouse',
#   'index': 904,
#   'total': 4415,
#   'text': "How what, Mother?'"},
#  {'title': 'slaughterhouse',
#   'index': 905,
#   'total': 4415,
#   'text': 'he prompted.'},
#  {'title': 'slaughterhouse',
#   'index': 906,
#   'total': 4415,
#   'text': 'She swallowed hard, shed some tears.'},
#  {'title': 'slaughterhouse',
#   'index': 907,
#   'total': 4415,
#   'text': 'Then she gathered energy from all over her ruined body, even from her toes and fingertips.'},
#  {'title': 'slaughterhouse',
#   'index': 908,
#   'total': 4415,
#   'text': "At last she bad accumulated enough to whisper this complete sentence: 'How did I get so oldl ’"},
#  {'title': 'slaughterhouse',
#   'index': 909,
#   'total': 4415,
#   'text': "Billy's antique mother passed out, and Billy was led from the room by a pretty nurse."},
#  {'title': 'slaughterhouse',
#   'index': 910,
#   'total': 4415,
#   'text': 'The body of an old man covered by a sheet was wheeled by just as Billy entered the corridor.'},
#  {'title': 'slaughterhouse',
#   'index': 911,
#   'total': 4415,
#   'text': 'The man had been a famous marathon runner in his day.'},
#  {'title': 'slaughterhouse',
#   'index': 912,
#   'total': 4415,
#   'text': 'So it goes.'},
#  {'title': 'slaughterhouse',
#   'index': 913,
#   'total': 4415,
#   'text': 'This was before Billy had his head broken in an airplane crash, by the way-before he became so vocal about flying saucers and traveling in time.'},
#  {'title': 'slaughterhouse',
#   'index': 914,
#   'total': 4415,
#   'text': 'Billy sat down in a waiting room.'},
#  {'title': 'slaughterhouse',
#   'index': 915,
#   'total': 4415,
#   'text': 'He wasn’t a widower yet.'},
#  {'title': 'slaughterhouse',
#   'index': 916,
#   'total': 4415,
#   'text': 'He sensed something hard under the cushion of his overstuffed chair.'},
#  {'title': 'slaughterhouse',
#   'index': 917,
#   'total': 4415,
#   'text': 'He dug it out, discovered that it was a book, The Execution of Private Slovik, by William Bradford Huie.'},
#  {'title': 'slaughterhouse',
#   'index': 918,
#   'total': 4415,
#   'text': 'It was a true account of the death before an American firing squad of private Eddie D. Slovik, 36896415, the only American soldier to be shot for cowardice since the Civil War.'},
#  {'title': 'slaughterhouse',
#   'index': 919,
#   'total': 4415,
#   'text': 'So it goes.'},
#  {'title': 'slaughterhouse',
#   'index': 920,
#   'total': 4415,
#   'text': "Billy read the opinion of a staff judge advocate who reviewed Slovik's case, which ended like this"},
#  {'title': 'slaughterhouse',
#   'index': 921,
#   'total': 4415,
#   'text': ': He has directly challenged the authority of the government, and future discipline depends upon a resolute reply to this challenge.'},
#  {'title': 'slaughterhouse',
#   'index': 922,
#   'total': 4415,
#   'text': 'If the death penalty is ever to be imposed for desertion, it should be imposed in this case, not as a punitive measure nor as retribution, but to maintain that discipline upon which alone an army can succeed against the enemy.'},
#  {'title': 'slaughterhouse',
#   'index': 923,
#   'total': 4415,
#   'text': 'There was no recommendation for clemency in the case and none is here recommended.'},
#  {'title': 'slaughterhouse',
#   'index': 924,
#   'total': 4415,
#   'text': 'So it goes.'},
#  {'title': 'slaughterhouse',
#   'index': 925,
#   'total': 4415,
#   'text': 'Billy bli nk ed in 1965, traveled in time to 1958.'},
#  {'title': 'slaughterhouse',
#   'index': 926,
#   'total': 4415,
#   'text': 'He was at a banquet in honour of a Little League team of which his son Robert was a member.'},
#  {'title': 'slaughterhouse',
#   'index': 927,
#   'total': 4415,
#   'text': 'The coach, who had never been married, was speaking.'},
#  {'title': 'slaughterhouse',
#   'index': 928,
#   'total': 4415,
#   'text': "He was all choked up. '"},
#  {'title': 'slaughterhouse',
#   'index': 929,
#   'total': 4415,
#   'text': "Honest to God,’ he was Saying, 'I'd consider it an honor just to be water boy for these kids.'"},
#  {'title': 'slaughterhouse',
#   'index': 930,
#   'total': 4415,
#   'text': 'Billy blinked in 1958, traveled in time to 1961.'},
#  {'title': 'slaughterhouse',
#   'index': 931,
#   'total': 4415,
#   'text': "It was New Year's Eve, and Billy was disgracefully drunk at a party where everybody was in optometry or married to an optometrist."},
#  {'title': 'slaughterhouse',
#   'index': 932,
#   'total': 4415,
#   'text': 'Billy usually didn’t drink much, because the war had ruined his stomach, but he certainly had a snootful now, and he was being unfaithful to his wife Valencia for the first and only time.'},
#  {'title': 'slaughterhouse',
#   'index': 933,
#   'total': 4415,
#   'text': 'He had somehow persuaded a woman to come into the laundry room of the house, and then sit up on the gas dryer, which was running.'},
#  {'title': 'slaughterhouse',
#   'index': 934,
#   'total': 4415,
#   'text': "The woman was very drunk herself, and she helped Billy get her girdle off. '"},
#  {'title': 'slaughterhouse',
#   'index': 935,
#   'total': 4415,
#   'text': "What was it you wanted to talk about?'"},
#  {'title': 'slaughterhouse',
#   'index': 936,
#   'total': 4415,
#   'text': "she said. '"},
#  {'title': 'slaughterhouse',
#   'index': 937,
#   'total': 4415,
#   'text': "It's all night,' said Billy."},
#  {'title': 'slaughterhouse',
#   'index': 938,
#   'total': 4415,
#   'text': 'He honestly thought it was all right.'},
#  {'title': 'slaughterhouse',
#   'index': 939,
#   'total': 4415,
#   'text': "He couldn’t remember the name of the woman. '"},
#  {'title': 'slaughterhouse',
#   'index': 940,
#   'total': 4415,
#   'text': "How come they call you Billy instead of William?' '"},
#  {'title': 'slaughterhouse',
#   'index': 941,
#   'total': 4415,
#   'text': "Business reasons,' said Billy."},
#  {'title': 'slaughterhouse',
#   'index': 942,
#   'total': 4415,
#   'text': 'That was true.'},
#  {'title': 'slaughterhouse',
#   'index': 943,
#   'total': 4415,
#   'text': 'His father-in-law, who owned the Ilium School of Optometry, who had set Billy up in practice, was a genius in his field.'},
#  {'title': 'slaughterhouse',
#   'index': 944,
#   'total': 4415,
#   'text': 'He told Billy to encourage people to call him Billy-because it would stick in their memories.'},
#  {'title': 'slaughterhouse',
#   'index': 945,
#   'total': 4415,
#   'text': 'It would also make him seem slightly magical, since there weren’t any other grown Billys around.'},
#  {'title': 'slaughterhouse',
#   'index': 946,
#   'total': 4415,
#   'text': 'It also compelled people to think of him as a friend right away.'},
#  {'title': 'slaughterhouse',
#   'index': 947,
#   'total': 4415,
#   'text': 'Somewhere in there was an awful scene, with people expressing disgust for Billy and the woman, and Billy found himself out in his automobile, trying to find the steering wheel.'},
#  {'title': 'slaughterhouse',
#   'index': 948,
#   'total': 4415,
#   'text': 'The main thing now was to find the steering wheel.'},
#  {'title': 'slaughterhouse',
#   'index': 949,
#   'total': 4415,
#   'text': 'At first, Billy windmilled his arms, hoping to find it by luck.'},
#  {'title': 'slaughterhouse',
#   'index': 950,
#   'total': 4415,
#   'text': 'When that didn’t work, he became methodical, working in such a way that the wheel could not possibly escape him.'},
#  {'title': 'slaughterhouse',
#   'index': 951,
#   'total': 4415,
#   'text': 'He placed himself hard against the left-hand door, searched every square inch of the area before him.'},
#  {'title': 'slaughterhouse',
#   'index': 952,
#   'total': 4415,
#   'text': 'When he failed to find the wheel, he moved over six inches, and searched again.'},
#  {'title': 'slaughterhouse',
#   'index': 953,
#   'total': 4415,
#   'text': 'Amazingly, he was eventually hard against the right-hand door, without having found the wheel.'},
#  {'title': 'slaughterhouse',
#   'index': 954,
#   'total': 4415,
#   'text': 'He concluded that somebody had stolen it.'},
#  {'title': 'slaughterhouse',
#   'index': 955,
#   'total': 4415,
#   'text': 'This angered him as he passed out.'},
#  {'title': 'slaughterhouse',
#   'index': 956,
#   'total': 4415,
#   'text': 'He was in the back seat of his car, which was why he couldn’t find the steering wheel.'},
#  {'title': 'slaughterhouse',
#   'index': 957,
#   'total': 4415,
#   'text': 'Now somebody was shaking Billy awake.'},
#  {'title': 'slaughterhouse',
#   'index': 958,
#   'total': 4415,
#   'text': 'Billy stiff felt drunk, was still angered by the stolen steering wheel.'},
#  {'title': 'slaughterhouse',
#   'index': 959,
#   'total': 4415,
#   'text': 'He was back in the Second World War again, behind the German lines.'},
#  {'title': 'slaughterhouse',
#   'index': 960,
#   'total': 4415,
#   'text': 'The person who was shaking him was Roland Weary.'},
#  {'title': 'slaughterhouse',
#   'index': 961,
#   'total': 4415,
#   'text': "Weary had gathered the front of Billy's field jacket into his hands."},
#  {'title': 'slaughterhouse',
#   'index': 962,
#   'total': 4415,
#   'text': 'He banged Billy against a tree, then puffed him away from it, flung him in the direction he was supposed to take under his own power.'},
#  {'title': 'slaughterhouse',
#   'index': 963,
#   'total': 4415,
#   'text': "Billy stopped, shook his head. '"},
#  {'title': 'slaughterhouse',
#   'index': 964,
#   'total': 4415,
#   'text': 'You go on,’ he said.'},
#  {'title': 'slaughterhouse', 'index': 965, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 966,
#   'total': 4415,
#   'text': "What? ’ 'You guys go on without me."},
#  {'title': 'slaughterhouse',
#   'index': 967,
#   'total': 4415,
#   'text': "I'm all right."},
#  {'title': 'slaughterhouse', 'index': 968, 'total': 4415, 'text': "’ '"},
#  {'title': 'slaughterhouse',
#   'index': 969,
#   'total': 4415,
#   'text': "You're what?' '"},
#  {'title': 'slaughterhouse',
#   'index': 970,
#   'total': 4415,
#   'text': "I'm O.K.’ 'Jesus-I’d hate to see somebody sick,' said Weary, through five layers of humid scarf from home."},
#  {'title': 'slaughterhouse',
#   'index': 971,
#   'total': 4415,
#   'text': "Lilly had never seen Weary's face."},
#  {'title': 'slaughterhouse',
#   'index': 972,
#   'total': 4415,
#   'text': 'He had tried to imagine it one time, had imagined a toad in a fishbowl.'},
#  {'title': 'slaughterhouse',
#   'index': 973,
#   'total': 4415,
#   'text': 'Weary kicked and shoved Billy for a quarter of a mile.'},
#  {'title': 'slaughterhouse',
#   'index': 974,
#   'total': 4415,
#   'text': 'The scouts were waiting between the banks of a frozen creek.'},
#  {'title': 'slaughterhouse',
#   'index': 975,
#   'total': 4415,
#   'text': 'They had heard the dog.'},
#  {'title': 'slaughterhouse',
#   'index': 976,
#   'total': 4415,
#   'text': 'They had heard men calling back and forth, too-calling like hunters who had a pretty good idea of where their quarry was.'},
#  {'title': 'slaughterhouse',
#   'index': 977,
#   'total': 4415,
#   'text': 'The banks of the creek were high enough to allow the scouts, to stand without being seen.'},
#  {'title': 'slaughterhouse',
#   'index': 978,
#   'total': 4415,
#   'text': 'Billy staggered down the bank ridiculously.'},
#  {'title': 'slaughterhouse',
#   'index': 979,
#   'total': 4415,
#   'text': "After him came Weary, clanking and clinking and tinkling and hot. '"},
#  {'title': 'slaughterhouse',
#   'index': 980,
#   'total': 4415,
#   'text': "Here he is, boys,' said Weary. '"},
#  {'title': 'slaughterhouse',
#   'index': 981,
#   'total': 4415,
#   'text': "He don’t want to live, but he's gonna live anyway."},
#  {'title': 'slaughterhouse',
#   'index': 982,
#   'total': 4415,
#   'text': "When he gets out of this, by God, he's gonna owe his life to the Three Musketeers."},
#  {'title': 'slaughterhouse', 'index': 983, 'total': 4415, 'text': '’'},
#  {'title': 'slaughterhouse',
#   'index': 984,
#   'total': 4415,
#   'text': 'Billy Pilgrim, there in the creekbed, thought he, Billy Pilgrim, was turning to steam painlessly.'},
#  {'title': 'slaughterhouse',
#   'index': 985,
#   'total': 4415,
#   'text': "If everybody would leave him alone for just a little while, he thought, he wouldn't cause anybody any more trouble."},
#  {'title': 'slaughterhouse',
#   'index': 986,
#   'total': 4415,
#   'text': 'He would turn to steam and float up among the treetops.'},
#  {'title': 'slaughterhouse',
#   'index': 987,
#   'total': 4415,
#   'text': 'Somewhere the big dog barked again.'},
#  {'title': 'slaughterhouse',
#   'index': 988,
#   'total': 4415,
#   'text': 'With the help of fear and echoes and winter silences, that dog had a voice like a big bronze gong.'},
#  {'title': 'slaughterhouse',
#   'index': 989,
#   'total': 4415,
#   'text': "Roland Weary, eighteen years old, insinuated himself between the scouts, draped a heavy arm around the shoulder of each. '"},
#  {'title': 'slaughterhouse',
#   'index': 990,
#   'total': 4415,
#   'text': 'So what do the Three Musketeers do now?'},
#  {'title': 'slaughterhouse',
#   'index': 991,
#   'total': 4415,
#   'text': '’ he said.'},
#  {'title': 'slaughterhouse',
#   'index': 992,
#   'total': 4415,
#   'text': 'Billy Pilgrim was having a delightful hallucination.'},
#  {'title': 'slaughterhouse',
#   'index': 993,
#   'total': 4415,
#   'text': 'He was wearing dry, wann, white sweatsocks, and he was skating on a ballroom floor.'},
#  {'title': 'slaughterhouse',
#   'index': 994,
#   'total': 4415,
#   'text': 'Thousands cheered.'},
#  {'title': 'slaughterhouse',
#   'index': 995,
#   'total': 4415,
#   'text': 'This wasn’t time-travel.'},
#  {'title': 'slaughterhouse',
#   'index': 996,
#   'total': 4415,
#   'text': 'It had never happened, never would happen.'},
#  {'title': 'slaughterhouse',
#   'index': 997,
#   'total': 4415,
#   'text': 'It was the craziness of a dying young man with his shoes full of snow.'},
#  {'title': 'slaughterhouse',
#   'index': 998,
#   'total': 4415,
#   'text': 'One scout hung his head, let spit fall from his lips.'},
#  {'title': 'slaughterhouse',
#   'index': 999,
#   'total': 4415,
#   'text': 'The other did the same.'},
#  ...]

# %%
#combined = sentences + goat_sents
sentences = sentences + goat_sents  + kite_sents  + johnny_sents  + catalonia_sents   +  western_sents  + tolls_sents  + floating_sents  + factotum_sents  + catch_sents  + slaughterhouse_sents  # will add to sentences directly

# %% [markdown]
# Just to make sure it worked, we'll print out a random sentence:

# %%
import random

# %%
random.choice(sentences)
# Out:
# {'title': '',
#  'index': 1616,
#  'total': 12672,
#  'text': 'I was going to win, and I was going to run that last kite.'}

# %% [markdown]
# Note: You can make your own corpus that works with the code in this notebook by exporting your data in TSV format with one line per sentence, with columns for the following:
#
# * `title`: the title of the work that the sentence comes from
# * `index`: the index of the sentence in the work
# * `total`: the total number of sentences in the work
# * `text`: the text of the sentence

# %% [markdown]
# Right off the bat, the spaCy library gives us access to a number of interesting units of text:
#
# * All of the sentences (`doc.sents`)
# * All of the words (`doc`)
# * All of the "named entities," like names of places, people, #brands, etc. (`doc.ents`)
# * All of the "noun chunks," i.e., nouns in the text plus surrounding matter like adjectives and articles
#
# The cell below, we extract these into variables so we can play around with them a little bit. (Parsing sentences is hungry work and the following cell will take a while to execute.)

# %%
words = []
noun_chunks = []
entities = []
# only use 5000 sentences sampled at random by default; comment out this `for...`
# uncomment the `for...` beneath to use every sentence in the corpus.
for i, sent in enumerate(random.sample(sentences, 10000)):
#for i, sent in enumerate(sentences):
    if i % 100 == 0:
        print(i, len(sentences))
    doc = nlp(sent['text'])
    words.extend([w for w in list(doc) if w.is_alpha])
    noun_chunks.extend(list(doc.noun_chunks))
    entities.extend(list(doc.ents))
# Out:
# 0 91908
# 100 91908
# 200 91908
# 300 91908
# 400 91908
# 500 91908
# 600 91908
# 700 91908
# 800 91908
# 900 91908
# 1000 91908
# 1100 91908
# 1200 91908
# 1300 91908
# 1400 91908
# 1500 91908
# 1600 91908
# 1700 91908
# 1800 91908
# 1900 91908
# 2000 91908
# 2100 91908
# 2200 91908
# 2300 91908
# 2400 91908
# 2500 91908
# 2600 91908
# 2700 91908
# 2800 91908
# 2900 91908
# 3000 91908
# 3100 91908
# 3200 91908
# 3300 91908
# 3400 91908
# 3500 91908
# 3600 91908
# 3700 91908
# 3800 91908
# 3900 91908
# 4000 91908
# 4100 91908
# 4200 91908
# 4300 91908
# 4400 91908
# 4500 91908
# 4600 91908
# 4700 91908
# 4800 91908
# 4900 91908
# 5000 91908
# 5100 91908
# 5200 91908
# 5300 91908
# 5400 91908
# 5500 91908
# 5600 91908
# 5700 91908
# 5800 91908
# 5900 91908
# 6000 91908
# 6100 91908
# 6200 91908
# 6300 91908
# 6400 91908
# 6500 91908
# 6600 91908
# 6700 91908
# 6800 91908
# 6900 91908
# 7000 91908
# 7100 91908
# 7200 91908
# 7300 91908
# 7400 91908
# 7500 91908
# 7600 91908
# 7700 91908
# 7800 91908
# 7900 91908
# 8000 91908
# 8100 91908
# 8200 91908
# 8300 91908
# 8400 91908
# 8500 91908
# 8600 91908
# 8700 91908
# 8800 91908
# 8900 91908
# 9000 91908
# 9100 91908
# 9200 91908
# 9300 91908
# 9400 91908
# 9500 91908
# 9600 91908
# 9700 91908
# 9800 91908
# 9900 91908

# %% [markdown]
# Ten random entities:

# %%
for item in random.sample(entities, 10):
    print(item.text)
# Out:
# Amir
# American
# Hulk
# three inches
# that month
# 86
# a thousand
# Washington Irving's
# Cathcart
# Anyway

# %% [markdown]
# the audacious cat   cahsed  the dog into     the subway station.
# det adjevtive noun verb det noun preposition det noun   noun

# %% [markdown]
# ### Grammatical roles
#
# The parser included with spaCy can also give us information about the grammatical roles in the sentence. For example, the `.root.dep_` attribute of a noun chunk tells us whether that noun chunk is the subject of the sentence ("nsubj") or a direct object ("dobj") of the sentence. (See the "Universal Dependency Labels" of spaCy's [annotation specs](https://spacy.io/api/annotation) for more possible roles.) Using this information, we can make a list of sentence subjects and sentence objects:

# %%
subjects = [chunk for chunk in noun_chunks if chunk.root.dep_ == 'nsubj']
objects = [chunk for chunk in noun_chunks if chunk.root.dep_ == 'dobj']

# %%
random.sample(subjects, 10)
# Out:
# [he, I, a scientist, I, Yossarian, anybody, Something, it, money, I]

# %%
random.sample(objects, 10)
# Out:
# [How much dialectics,
#  a man,
#  Adam,
#  his material,
#  us,
#  Pablo,
#  the question,
#  ourselves,
#  a swim,
#  something]

# %% [markdown]
# ### Parts of speech
#
# The spaCy parser allows us to check what part of speech a word belongs to. In the cell below, we create four different lists—`nouns`, `verbs`, `adjs` and `advs`—that contain only words of the specified parts of speech. Using the `.tag_` attribute, we can easily get only particular forms of verbs; in this case, I'm just getting verbs that are in the past tense. ([There's a full list of part of speech tags here](https://spacy.io/docs/usage/pos-tagging#pos-tagging-english).)

# %%
nouns = [w for w in words if w.pos_ == "NOUN"]
verbs = [w for w in words if w.pos_ == "VERB"]
past_tense_verbs = [w for w in words if w.tag_ == 'VBD']
adjs = [w for w in words if w.tag_ == "JJ"]
advs = [w for w in words if w.pos_ == "ADV"]

# %% [markdown]
# And now we can print out a random sample of any of these:

# %%
for item in random.sample(adjs, 12): # change "nouns" to "verbs" or "adjs" or "advs" to sample from those lists!
    print(item.text)
# Out:
# oily
# smoky
# open
# real
# old
# new
# dizzy
# surly
# eyed
# Big
# clear
# bent

# %% [markdown]
# ### Entity types
#
# The parser in spaCy not only identifies "entities" but also assigns them to a particular type. [See a full list of entity types here.](https://spacy.io/docs/usage/entity-recognition#entity-types) Using this information, the following cell builds lists of the people, locations, and times mentioned in the text:

# %%
people = [e for e in entities if e.label_ == "PERSON"]
locations = [e for e in entities if e.label_ == "LOC"]
times = [e for e in entities if e.label_ == "TIME"]

# %% [markdown]
# And then you can print out a random sample:

# %%
for item in random.sample(times, 12): # change "times" to "people" or "locations" to sample those lists
    print(item.text.strip())
# Out:
# morning
# the next morning
# twenty-four hours
# nearly an hour
# noon
# earlier in the morning
# morning
# late afternoon
# a few minutes
# about fifteen minutes
# the last minutes
# night

# %% [markdown]
# ### Finding the most common
#
# We won't go too deep into text analysis in this tutorial, but it's useful to be able to do the most fundamental task in text analysis: finding the things that are most common. The code to do this task looks like the following, which gives us a way to look up how often any word occurs in the text:

# %%
from collections import Counter
word_count = Counter([w.text for w in words])

# %%
word_count['ship']
# Out:
# 4

# %%
word_count['art']
# Out:
# 8

# %%
word_count['attack']
# Out:
# 22

# %%
word_count['beauty']
# Out:
# 2

# %%
people_count = Counter([w.text for w in people])

# %%
people_count.most_common(12)
# Out:
# [('Robert Jordan', 111),
#  ('Hassan', 54),
#  ('Baba', 48),
#  ('Maria', 34),
#  ('Billy', 29),
#  ('Aarfy', 22),
#  ('Ali', 21),
#  ('Milo', 20),
#  ('Agustin', 19),
#  ('Jane', 19),
#  ('Anselmo', 18),
#  ('Cathcart', 17)]

# %% [markdown]
# ### When do things happen in this text?
#
# Here's another example. Using the `times` entities, we can make a spreadsheet of how often particular "times" (durations, times of day, etc.) are mentioned in the text.

# %%
time_counter = Counter([e.text.lower().strip() for e in times])
save_counter_tsv("time_count.tsv", time_counter, 100)

# %% [markdown]
# Do the same thing, but with people:

# %%
people_counter = Counter([e.text.lower() for e in people])
save_counter_tsv("people_count.tsv", people_counter, 100)

# %% [markdown]
# ### Generating stories from a corpus and Tracery grammars
#
# Once you've isolated entities and parts of speech, you can recombine them in interesting ways. One is to use a Tracery grammar to write sentences that include the isolated parts. Because the parts have been labelled using spaCy, you can be reasonbly sure that they'll fit into particular slots in the sentence. (I used a similar technique for my [Cheap Space Nine](https://twitter.com/cheapspacenine) bot.)

# %%
import tracery
from tracery.modifiers import base_english

# %%
rules = {
    "subject": [w.text for w in subjects],
    "object": [w.text for w in objects],
    "verb": [w.text for w in past_tense_verbs],
    "adj": [w.text for w in adjs],
    "people": [w.text for w in people],
    "loc": [w.text for w in locations],
    "time": [w.text for w in times],
    "origin": "#flashback#\n\n[charA:#subject#][charB:#subject#][prop:#object#]#sentences#",

    "flashback": " - Flashback - : #loc#, #time.lowercase#",
    "sentences": [
        "'I don't sleep much, because when I do, I dream about  #object.lowercase#.' #charA# said."
        "#sentence#\n#sentence#", "#sentence#\n#sentence#\n#sentence#",
        "#sentence#\n#sentence#\n#sentence#", "#sentence#\n#sentence#", 
        "#sentence#\n#sentence#\n#sentence#\n#sentence#"
    ],
    "sentence": [
        "I wasn't sure if these were #charA.capitalize#'s limbs or mine.",
        "#charA.capitalize# #verb# #prop#.",
        "#charB.capitalize# #verb# #prop#.",
        "#prop.capitalize# became #adj#.",
        "#prop.capitalize# exploded in #loc#.",
        "#charA.capitalize# and #charB# looked at each other.",
        "'Did you hear about #object.lowercase#?' said #charA#.",
        "'#subject.capitalize# is #adj#,' said #charB#.",
        "#charA.capitalize# and #charB# #verb# #object#.",
        "#charA.capitalize# was chasing #charB#",
        "#charB# tried to hide",
        "#sentence#\n#sentence#"
    ]
}

# %%
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)

# %%
for i in range(5):
    print(grammar.flatten("#origin#"))
    print()
# Out:
#  - Flashback - : Europe, an hour later
#
# he tried to hide
# he tried to hide
# I wasn't sure if these were He's limbs or mine.
#
#  - Flashback - : North America, every night
#
# What became nice.
# He had What.
# What exploded in Civil Guards.
# I wasn't sure if these were He's limbs or mine.
#
#  - Flashback - : Cole Creek, every morning
#
# He and we parted all that crap.
# Some honor became good.
# He and we was a hole.
#
#  - Flashback - : the Assault Guards, less than two hours later
#
# Long rifles and Baba looked at each other.
# Position became hateful.
# Long rifles and Baba was offer.
# Long rifles was chasing Baba
#
#  - Flashback - : Europe, one night
#
# 'I don't sleep much, because when I do, I dream about  me.' she said.It became many.
# I wasn't sure if these were She's limbs or mine.

# %% [markdown]
# ## Markov chain text generation
#
# Another way to produce new narratives from existing narrative text is to find statistical patterns in the text itself and then make the computer create new text that follows those statistical patterns. Markov chain text generation has been a pastime of poets and programmers going back [all the way to 1983](https://www.jstor.org/stable/24969024), so it should be no surprise that there are many implementations of the idea in Python that you can download and install. The one we're going to use is [Markovify](https://github.com/jsvine/markovify), a Markov chain text generation library originally developed for BuzzFeed, apparently. Writing [code to implement a Markov chain generator](https://github.com/aparrish/rwet/blob/master/ngrams-and-markov-chains.ipynb) on your own is certainly possible, but Markovify comes with a lot of extra niceties that will make our lives easier.

# %% [markdown]
# To install Markovify on your computer, run the cell below. (You can skip this step if you're using this notebook in Binder.)

# %%
# !pip install markovify
# Out:
# Collecting markovify
#   Downloading https://files.pythonhosted.org/packages/99/b7/a5cf39283f08c8013623dbcf67063b0215942ae464fc864eca1434d050e1/markovify-0.7.2.tar.gz
# Collecting unidecode (from markovify)
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#     100% |████████████████████████████████| 245kB 7.5MB/s ta 0:00:01
# Building wheels for collected packages: markovify
#   Running setup.py bdist_wheel for markovify ... done
#   Stored in directory: /Users/alizarinwaissberg/Library/Caches/pip/wheels/0c/19/38/b901adb8ab0721a6c8c86f468e48b22f3ecf08560e6aeb99fa
# Successfully built markovify
# Installing collected packages: unidecode, markovify
# Successfully installed markovify-0.7.2 unidecode-1.1.1

# %% [markdown]
# And then run this cell to make the library available in your notebook:

# %%
import markovify

# %% [markdown]
# We need a list of strings to train the Markov generator. For now, let's just get all of the sentences from any movie in the corpus:

# %%
all_text = [item['text'] for item in sentences]

# %% [markdown]
# The code in the following cell creates a new text generator, using the text in the variable specified to build the Markov model, which is then assigned to the variable `all_text_gen`.

# %%
all_text_gen = markovify.Text(all_text)

# %% [markdown]
# You can then call the `.make_sentence()` method to generate a sentence from the model:

# %%
print(all_text_gen.make_sentence())
# Out:
# The calloused pads of his rifle and machine gun firing around the boy.

# %% [markdown]
# The `.make_short_sentence()` method allows you to specify a maximum length for the generated sentence:

# %%
print(all_text_gen.make_short_sentence(50))
# Out:
# Then I try to blow the bridge and I love thee so.

# %% [markdown]
# By default, Markovify tries to generate a sentence that is significantly different from any existing sentence in the input text. As a consequence, sometimes the `.make_sentence()` or `.make_short_sentence()` methods will return `None`, which means that in ten tries it wasn't able to generate such a sentence. You can work around this by increasing the number of times it tries to generate a sufficiently unique sentence using the `tries` parameter:

# %%
print(all_text_gen.make_short_sentence(40, tries=100))
# Out:
# I would like to save ourselves.

# %% [markdown]
# Or by disabling the check altogether with `test_output=False`:

# %%
print(all_text_gen.make_short_sentence(40, test_output=False))
# Out:
# ’ said Danny.

# %% [markdown]
# ### Changing the order
#
# When you create the model, you can specify the order of the model using the `state_size` parameter. It defaults to 2. Let's make two model with different orders and compare:

# %%
gen_1 = markovify.Text(all_text, state_size=1)
gen_2 = markovify.Text(all_text, state_size=2)
gen_3 = markovify.Text(all_text, state_size=3)
gen_4 = markovify.Text(all_text, state_size=4)
gen_5 = markovify.Text(all_text, state_size=5)
gen_15 = markovify.Text(all_text, state_size=15)

# %%
print(gen_1.make_sentence(test_output=False))
print(gen_2.make_sentence(test_output=False))
print(gen_3.make_sentence(test_output=False))
print(gen_4.make_sentence(test_output=False))
print(gen_5.make_sentence(test_output=False))
print(gen_15.make_sentence(test_output=False))
# Out:
# I’d said this way I think of wartime conditions of each day when they select these years old.
# As if I pull myself in.
# he said.
# indeed, I recognized one of them.
# We walked past rooms with no floor covering but matted carpets and windows shuttered with sheets of plastic.
# Nay,” the corporal said.

# %% [markdown]
# In general, the higher the order, the more the sentences will seem "coherent" (i.e., more closely resembling the source text). Lower order models will produce more variation. Deciding on the order is usually a matter of taste and trial-and-error.

# %% [markdown]
# ### Changing the level
#
# Markovify, by default, works with *words* as the individual unit. It doesn't come out-of-the-box with support for character-level models. The following code defines a new kind of Markovify generator that implements character-level models. Execute it before continuing:

# %%
class SentencesByChar(markovify.Text):
    def word_split(self, sentence):
        return list(sentence)
    def word_join(self, words):
        return "".join(words)

# %% [markdown]
# Any of the parameters you passed to `markovify.Text` you can also pass to `SentencesByChar`. The `state_size` parameter still controls the order of the model, but now the n-grams are characters, not words.
#
# The following cell implements a character-level Markov text generator for the word "condescendences":

# %%
con_model = SentencesByChar("condescendences", state_size=5)

# %% [markdown]
# Execute the cell below to see the output—it'll be a lot like what we implemented by hand earlier!

# %%
con_model.make_sentence()

# %% [markdown]
# Of course, you can use a character-level model on any text of your choice. So, for example, the following cell creates a character-level order-7 Markov chain text generator from text A:

# %%
gen_char = SentencesByChar(all_text, state_size=7)

# %% [markdown]
# And the cell below prints out a random sentence from this generator. (The `.replace()` is to get rid of any newline characters in the output.)

# %%
print(gen_char.make_sentence(test_output=False))
# Out:
# but I think; he'll go astray.

# %% [markdown]
# ### Thinking about structure
#
# It's one thing to be able to produce one plausible sentence of a plot summary using Markov chains, but another to create a sense of overall structure between sentences, and generating narratives with these kinds of long-term dependencies is still an open problem in computational creativity. The approach I'm going to suggest below relies on the intuition that sentences in a plot summary share characteristics based on their position in the summary. First sentences will generally introduce characters and present an initial situation; last sentences will generally describe how the situation was resolved; and sentences in between will describe developing action.
#
# Following this intuition, let's create *three different Markov chains*: one for beginning sentences, one for middle sentences, and one for final sentences. We can use the `index` of each sentence in our corpus to give us this information.
#
# First, the beginnings are lines whose index is zero (i.e., they're the first sentence for this plot):

# %%
beginnings = [line['text'] for line in sentences if 0 <= line['index'] < 50]

# %%
nearbeginnings = [line['text'] for line in sentences if 50 <= line['index'] < 250]

# %%
random.sample(nearbeginnings, 5)
# Out:
# ['“',
#  'when the cold water met my face seems a probable one -- that all things in heaven and earth came clear to me, and I realized that this day I would make my last',
#  'When the jar on the floor was full, the jar feeding hiselbow was empty, and the two were simply switched quickly so that the stuff coulddrip back into him.',
#  '"',
#  'He was up.']

# %% [markdown]
# And endings are sentences that come last in the plot (i.e., their index is one less than the total number of sentences):

# %%
endings = [line['text'] for line in sentences if line['total'] - 20 <= line['index'] < line['total'] - 1]

# %%
nearendings = [line['text'] for line in sentences if line['total'] - 200 <= line['index'] < line['total'] - 20]

# %%
random.sample(nearendings, 10)
# Out:
# ['At the end of that slim back, that slim body, was an enormous behind.',
#  'Don’t you.?',
#  'Lucy Long!"',
#  '’',
#  'From high on his chair Capt.',
#  "They are spotted by a destroyer and have to dive below the submarine's rated limit.",
#  'he had it',
#  'He has been to Fort Bragg with a hamster.',
#  'We walked away.',
#  'He saw its call letters over the entrance of an office building, so he went in.']

# %% [markdown]
# And "middles" are anything in between:

# %%
middles = [line['text'] for line in sentences if 250 < line['index'] < line['total'] - 200]

# %%
random.sample(middles, 20)
# Out:
# ["Ah, here's a job for you.",
#  '"',
#  '“',
#  'very young guys and Ruby was the first and only girl they knew they were too shy with other girls with nice girls.',
#  'A cloud,’ he said.',
#  "Lazzaro, too, had been on Roland Weary's boxcar, and had given his word of honor to Weary that he would find some way to make Billy Pilgrim pay for Weary's death.",
#  '“',
#  'FOR WHOM THE BELL TOLLS',
#  'How many dots do you see?',
#  'Yes.',
#  'At the same time the pre-war armed police forces, Civil Guards, and so forth, had been brought back into use and were being heavily reinforced and armed.',
#  'It cures ever)’thing.',
#  'Billy also had charge of a portable altar, an olive-drab attache case with telescoping legs.',
#  '“',
#  'He was always *augmenting* things.',
#  'Benjamin crawled on his belly through some tall whitish weed till he was about twenty yards from the parapet and tried a challenge.',
#  'No.',
#  'Who is he?"',
#  'This wasn’t sleep-deprivation, and it wasn’t an attempt to induce the Bucha Effect.',
#  "It isn't like it was at the beginning."]

# %% [markdown]
# The following cell creates the models:

# %%
beginning_gen = markovify.Text(beginnings)
nearbeginnings_gen = markovify.Text(nearbeginnings)
middle_gen = markovify.Text(middles)
nearending_gen = markovify.Text(nearendings)
ending_gen = markovify.Text(endings)

# %% [markdown]
# Now you can generate tiny narratives by producing a beginning sentence, a middle sentence, and an ending sentence:

# %%
print(beginning_gen.make_short_sentence(100))
print(nearbeginnings_gen.make_short_sentence(100))
print(middle_gen.make_short_sentence(100))
print(nearending_gen.make_short_sentence(100))
print(ending_gen.make_short_sentence(100))
# Out:
# Since he knew saying that it is a high-level functionary at the camp, in return for money.
# Stubblebine years, 1981-4, almost as if it was a strange and heartening sight.
# We're not going to let him touch you?
# From where I was on top.
# As the war to be used in the English countryside of the town of Aberowen in 1911.

# %% [markdown]
# The narratives still feel disconnected (and there are often jarring mismatches in pronoun antecedents), but the artifacts produced with this method do feel a bit narrative-like? Maybe?

# %% [markdown]
# ### Combining models
#
# Markovify has a handy feature that allows you to *combine* models, creating a new model that draws on probabilities from both of the source models. You can use this to create hybrid output that mixes the style and content of two (or more!) different source texts. To do this, you need to create the models independently, and then call `.combine()` to combine them.
#
# The code below combines models for beginning sentences, middle sentences, and ending sentences into one model:

# %%
combo = markovify.combine([beginning_gen, middle_gen, ending_gen], [10, 1, 10])

# %% [markdown]
# The bit of code `[10, 1, 10]` controls the "weights" of the models, i.e., how much to emphasize the probabilities of any model. You can change this to suit your tastes. (E.g., if you want mostly beginnings with but a bit of middles and a *soupçon* of ends, try `[10, 2, 1]`.)
#
# Then you can create sentences using the combined model:

# %%
print(combo.make_short_sentence(120))
# Out:
# Meanwhile, there are horses in the hospital but nevermentioning why.

# %% [markdown]
# # The War Machine
# ### War Novel Generator

# %%
print("Chapter 1 - The Grudge");
print(beginning_gen.make_short_sentence(90));print(beginning_gen.make_short_sentence(100));print(beginning_gen.make_short_sentence(100))
print(beginning_gen.make_short_sentence(100)); print(beginning_gen.make_short_sentence(100));print(beginning_gen.make_short_sentence(100));print(beginning_gen.make_short_sentence(100))
print(beginning_gen.make_short_sentence(100)); print(beginning_gen.make_short_sentence(100));print(beginning_gen.make_short_sentence(100));print(beginning_gen.make_short_sentence(100))
print(beginning_gen.make_short_sentence(100)); print(beginning_gen.make_short_sentence(100));print(beginning_gen.make_short_sentence(100));print(beginning_gen.make_short_sentence(100))
print(" ");
print("-flashback-");


print(" ");

rules = {
    "subject": [w.text for w in subjects],
    "object": [w.text for w in objects],
    "verb": [w.text for w in past_tense_verbs],
    "adj": [w.text for w in adjs],
    "people": [w.text for w in people],
    "loc": [w.text for w in locations],
    "time": [w.text for w in times],
    "origin": "#flashback#\n\n[charA:#subject#][charB:#subject#][prop:#object#]#sentences#",

    "flashback": " - Flashback - : #loc#, #time.lowercase#",
    "sentences": [
        "'I don't sleep much, because when I do, I dream about  #object.lowercase#.' #charA# said."
        "#sentence#\n#sentence#", "#sentence#\n#sentence#\n#sentence#",
        "#sentence#\n#sentence#\n#sentence#", "#sentence#\n#sentence#", "#sentence#\n#sentence#\n#sentence#", "#sentence#\n#sentence#", 
        "#sentence#\n#sentence#\n#sentence#\n#sentence#",
        "#sentence#\n#sentence#", "#sentence#\n#sentence#\n#sentence#",
        "#sentence#\n#sentence#\n#sentence#", "#sentence#\n#sentence#", "#sentence#\n#sentence#\n#sentence#", "#sentence#\n#sentence#", 
        "#sentence#\n#sentence#\n#sentence#\n#sentence#"
    ],
    "sentence": [
        "I wasn't sure if these were #charA.capitalize#'s limbs or mine.",
        "#charA.capitalize# #verb# #prop#.",
        "#charB.capitalize# #verb# #prop#.",
        "#prop.capitalize# became #adj#.",
        "#prop.capitalize# exploded in #loc#.",
        "#charA.capitalize# and #charB# looked at each other.",
        "'Did you hear about #object.lowercase#?' said #charA#.",
        "'#subject.capitalize# is #adj#,' said #charB#.",
        "#charA.capitalize# and #charB# #verb# #object#.",
        "#charA.capitalize# was chasing #charB#",
        "#charB# tried to hide",
        "#sentence#\n#sentence#"
    ]
}
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
for i in range(4):
    print(grammar.flatten("#origin#"))
    print()

print(" ");
print("Chapter 2 - The Adversary");
print(nearbeginnings_gen.make_short_sentence(100));  print(nearbeginnings_gen.make_short_sentence(100));  print(nearbeginnings_gen.make_short_sentence(100)); 
print(nearbeginnings_gen.make_short_sentence(100));  print(nearbeginnings_gen.make_short_sentence(100)); 
print(nearbeginnings_gen.make_short_sentence(50, test_output=False)); print(nearbeginnings_gen.make_short_sentence(500, test_output=False));  
print(nearbeginnings_gen.make_short_sentence(50, test_output=False));  print(nearbeginnings_gen.make_short_sentence(500, test_output=False)); 
print(nearbeginnings_gen.make_short_sentence(50, test_output=False)); 
print(nearbeginnings_gen.make_short_sentence(100)); print(nearbeginnings_gen.make_short_sentence(150));  print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(100)); print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(100)); print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(50, test_output=False));
print(nearbeginnings_gen.make_short_sentence(100));  print(nearbeginnings_gen.make_short_sentence(100));  print(nearbeginnings_gen.make_short_sentence(100)); 
print(nearbeginnings_gen.make_short_sentence(100));  print(nearbeginnings_gen.make_short_sentence(100)); 
print(nearbeginnings_gen.make_short_sentence(50, test_output=False)); print(nearbeginnings_gen.make_short_sentence(500, test_output=False));  
print(nearbeginnings_gen.make_short_sentence(50, test_output=False));  print(nearbeginnings_gen.make_short_sentence(500, test_output=False)); 
print(nearbeginnings_gen.make_short_sentence(50, test_output=False)); 
print(nearbeginnings_gen.make_short_sentence(100)); print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(150)); 
print(nearbeginnings_gen.make_short_sentence(50, test_output=False));

print(" ");
print("Chapter 3 - The Armament")
print(gen_1.make_sentence(test_output=False)); print(gen_1.make_sentence(test_output=False)); print(gen_1.make_sentence(test_output=False))
print(gen_1.make_sentence(test_output=False)); print(gen_1.make_sentence(test_output=False)); print(gen_1.make_sentence(test_output=False))
print(gen_1.make_sentence(test_output=False)); print(gen_1.make_sentence(test_output=False)); print(gen_1.make_sentence(test_output=False))
print(gen_2.make_sentence(test_output=False))
print(gen_3.make_sentence(test_output=False))
print(gen_4.make_sentence(test_output=False))
print(gen_5.make_sentence(test_output=False))
print(gen_15.make_sentence(test_output=False))
print(gen_1.make_sentence(test_output=False))
print(gen_2.make_sentence(test_output=False))
print(gen_3.make_sentence(test_output=False))
print(gen_1.make_sentence(test_output=False))
print(gen_2.make_sentence(test_output=False))
print(gen_3.make_sentence(test_output=False))
print(gen_1.make_sentence(test_output=False))
print(gen_2.make_sentence(test_output=False))
print(gen_3.make_sentence(test_output=False))
print(gen_5.make_sentence(test_output=False))
print(gen_15.make_sentence(test_output=False)); print(gen_15.make_sentence(test_output=False));
print(gen_15.make_sentence(test_output=False)); print(gen_15.make_sentence(test_output=False)); print(gen_15.make_sentence(test_output=False))
print(gen_15.make_sentence(test_output=False)); print(gen_15.make_sentence(test_output=False))

print(" ");
print("Flashback");
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
for i in range(3):
    print(grammar.flatten("#origin#"))
    print()
print(" ");

print("Chapter 4 - The Stealth");
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(20, tries=100)); 
print(all_text_gen.make_short_sentence(15, tries=200)); 
print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); 
print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); print(middle_gen.make_short_sentence(50, test_output=False)); 
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(" ");

print("Chapter 5 - The Confrontation");
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence()); print(all_text_gen.make_sentence());
print(" ");

print("Chapter 6 - The Chase");
print(all_text_gen.make_short_sentence(50, tries=100)); print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100));  print(all_text_gen.make_short_sentence(30, tries=100));  print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100));  print(all_text_gen.make_short_sentence(30, tries=100));  print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(100)); 
print(all_text_gen.make_short_sentence(50, tries=100)); 
print(all_text_gen.make_short_sentence(30, tries=100)); 
print(all_text_gen.make_short_sentence(20, tries=100)); 
print(all_text_gen.make_short_sentence(15, tries=200)); 
print(" ");

print("Chapter 7 - The Interrogation");
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(300));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(300));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(300));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(300)); print(middle_gen.make_short_sentence(300)); print(middle_gen.make_short_sentence(300));
print(middle_gen.make_short_sentence(300)); print(middle_gen.make_short_sentence(300)); print(middle_gen.make_short_sentence(300));
print(" ");
print("Flashback");
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
for i in range(7):
    print(grammar.flatten("#origin#"))
    print()
print(" ");

print(" ");
print("Chapter 8 - The Inevitable Doom");
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));
print(middle_gen.make_short_sentence(100)); print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));print(middle_gen.make_short_sentence(100));
print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200)); print(middle_gen.make_short_sentence(200));

print(" ");

print("Chapter 9 - The Aftermath");
print(nearending_gen.make_short_sentence(30, tries=100)); print(nearending_gen.make_short_sentence(35, tries=100));
print(nearending_gen.make_short_sentence(55, tries=100));
print(nearending_gen.make_short_sentence(55, tries=100));
print(nearending_gen.make_short_sentence(55, tries=100));
print(nearending_gen.make_short_sentence(55, tries=100));
print(nearending_gen.make_short_sentence(55, tries=100));
print(nearending_gen.make_short_sentence(55, tries=100));
print(nearending_gen.make_short_sentence(30, tries=100));  print(all_text_gen.make_short_sentence(30, tries=100));  print(all_text_gen.make_short_sentence(30, tries=100)); print(all_text_gen.make_short_sentence(30, tries=100)); 
print(nearending_gen.make_short_sentence(30, tries=100));
print(nearending_gen.make_short_sentence(30, tries=100)); 
print(nearending_gen.make_short_sentence(30, tries=100)); 
print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(100));print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200));
print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(100));print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200));
print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(100));print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200));
print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(100));print(nearending_gen.make_short_sentence(100)); print(nearending_gen.make_short_sentence(100));
print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200)); print(nearending_gen.make_short_sentence(200));
print(nearending_gen.make_short_sentence(30, tries=100)); print(nearending_gen.make_short_sentence(35, tries=100));
print(nearending_gen.make_short_sentence(55, tries=100));
print(nearending_gen.make_short_sentence(65, tries=100));
print(" ");
print("Flashback");
grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english)
for i in range(9):
    print(grammar.flatten("#origin#"))
    print()


print(" ");
print("Epilogue");
print(ending_gen.make_short_sentence(100)); print(ending_gen.make_short_sentence(100)); 
print(ending_gen.make_short_sentence(100)); 
print(ending_gen.make_short_sentence(100)); 
print(ending_gen.make_short_sentence(100)); print(ending_gen.make_short_sentence(100)); 
print(ending_gen.make_short_sentence(100));
# Out:
# Chapter 1 - The Grudge
# I hoped he liked me as much as I can.
# Mona consents to live their lives, but they are forced to withdraw because of the crew.
# George trains for the jungle, and Joker chooses not to take a Household Science course.
# On the way during the Korean War, at which the students play up.
# Bannon finds that Millie is already married and an atheist.
# During the extensive bombing by the Germans he departs for the crimes of a very dangerous mission.
# When their men return and begin to look forward, with hope and anxiety, towards their repatriation.
# And I'm reminded, too, of the Allied invasion.
# So, at a mirror and a Green Beret.
# In Canada, British and Canadian forces are slowly driven back to Fowler as if nothing had happened.
# ” before passing out.
# Rivers, concerned for Prior's safety, finally recognises that his wife will divorce him.
# Joe attempts suicide by suffocation, but finds that the US Army.
# He crosses paths with Ashley, who is departing for the priesthood.
# In Nebraska, Barney's soldier friend leaves the U-boat sink at the depth of 280 metres.
#
# -flashback-
#
#  - Flashback - : Earth, a few minutes
#
# Dobbs tried to hide
# Dobbs was the Hazaras.
# You and Dobbs was a series.
# The Hazaras became new.
# I wasn't sure if these were You's limbs or mine.
#
#  - Flashback - : the Bucha Effect, an average night
#
# Jim and you gave a good day.
# I wasn't sure if these were Jim's limbs or mine.
# you tried to hide
#
#  - Flashback - : South, forty-five minutes
#
# He and he looked at each other.
# 'I is unjust,' said he.
# he tried to hide
# he tried to hide
# 'Did you hear about eric?' said he.
#
#  - Flashback - : the Civil Guards, next night
#
# The smoky blanket and I looked at each other.
# I tried to hide
#
#
# Chapter 2 - The Adversary
# If you use your mind to heal, you can thus drink from a few letters and papers.
# Everyone’s clothes followed the same way, as I'd thought
# Baba had bought it for the years I spent in the barrack square.
# ’ ’Call her up and surveys their surroundings.
# had about a week.
# ; I would write.
# The colonel had really been investigated.
# She doesn’t know yet,’ I said.
# You know that, Sandy?
# It was a long time.
# But there was no trail that the entire incident ofthe soldier in white.
# And I became a public relations in Baltimore.
# And we had to take us to the head was lower than the feet or if the head was plenty big.
# Yossarian wanted to help him release the horses.
# He glances anxiously at the leg with disgust.
# So I phoned this in, and the ’column’, which in practice meant any large number of a native tribe in Tarzan and the horses.
# I always wondered if he had a cavernous mouth, cavernous cheeks, cavernous, sad,mildewed eyes.
# You know,’ he said, ‘I’ve pretty much blocked the rest of that bright red sausage which tastes of soap and gives you diarrhoea.
# Yossarian was sorry for you
# He had slipped the pack off and many of the kind.
# He had an old-fashioned pocket watch on his living-room carpet and try to levitate.
# But I want to be kept out of a dreadful thing called The Committee on Social Thought.
# Yet whoever was above had been a Regular Army officer, and still not explain completely.
# One time they switched me from the quart on my insteps.
# You think we didn't notice it?
# The soldier in white, who had fed me to build a parapet–above all, how to use his weapons.
# But not for a moment we fall silent.
# I can bring as many as six in a subdued light.
# He used to travel around the ward again.
# Hours later, Robert finally sits up and get a head this big.
# I know.
# On my second day at the other end of his line.
# Hey Rudy.
# Mom's apple pie.
# Bursting the hearts of animals.
# How easy it is now.
# He is almost at a distance no greater than half an hour or so during the Cold War.
# Let's go into all of Kabul.
# We began to think of my mother's old history books.
# Later, in the railroads.
# He was a stout, fresh-faced, pleasant young man could see a large dark room.
# I am not writing a book about Dresden.
# How many men as a latrine; so had all the thought and talk.
# Listen, I'm a bachelor.
#
# Chapter 3 - The Armament
# Billy couldn’t imagine jumping into the bursts of which has ever took from people knocked out.
# No, we ran an interminable nights that night: he was only took more effectively to discover what I’m thinking,’ said to the bushes, from Shale City with stained around the room stirred in the other men were all the left hand clutching at the narrative is ignoble,” Anselmo said Corporal Whitcomb in the rest were not exerted by Milo'scrushing bereavement.
# Now go.
# There was an affirmation of the ignition and a hill.
# And also shouting to watch, this time she wouldn’t have said and you have only thing I knew I'd jumped back into your step.
# Now there was hanged himself.
# The way off than his hairline.
# Had
# But to slip in.
# Politically, he was trying to drive the fastidious, clean-living bastards out with another harsh cryand whipped him upward and downward through the area.
# He glanced into the dixie.
# *
# Dobbs screamed back at them, and stood up on a rickety woodenchair, waving the gun wildly.
# “
# This charge was a wonderful in that even had his maturity and no other buildings just a touch that way.
# “
# Assef snickered.
# Our uniforms of the trail but
# Abu Ghraib jail on the floor beside the road, the sentry at the body of his cucumber picklers.
# A wave of startled uneasiness broke over theofficers on the dais, and even Major Danby, who had begun synchronizing thewatches, was distracted momentarily as he counted out the seconds and minutes which was as dangerous to their own lines.
# 85 CHAPTER TWENTY-ONE
# Don’t talk to her.
# He did not know this.
# You know, I'm not a clothes man.
# An old man, he learns of the ruin of his communist superiors, and of the success of some of his Nationalist acquaintances in Taiwan.
# I had thought earlier in the night that you can’t run when you are sodden from head to foot and weighted down with a rifle and cartridges; I learned now you can always run when you think you have fifty or a hundred armed men after you.
# Let them debate the menace of the yellow race and the white man's burden and the course of empire and why should we take all this crap off Germany or whoever the next Germany is.
# The chief excitement was the arrival of Fascist deserters, who were brought under guard from the front line.
# “
# “
# Much.
#
# Flashback
#  - Flashback - : Cole Creek, a sunny morning
#
# Any moremissions became light.
# Everybody was chasing I
# Everybody and I looked at each other.
#
#  - Flashback - : Earth, night
#
# I told a livercondition.
# A livercondition exploded in Europe.
# I wasn't sure if these were I's limbs or mine.
# she tried to hide
#
#  - Flashback - : Escorial, evening
#
# 'I don't sleep much, because when I do, I dream about  ball.' I said.No attention became high.
# 'I is other,' said I.
#
#
# Chapter 4 - The Stealth
# He wanted to know.
# and then are they like now, and a fine time.
# It would not happen.
# Pay no attention to it.
# The affair was that my nerves on edge.
# You know what will befall him.?
# Discipline must come here.
# Even a man at his passing.
# That's what you mean, you bastard,
# He put the glasses again.
# You only heard the tank corps.
# ; I was nuts.
# None
# Echanis told me, a vow to have
# What do I feed—
# Three women come strolling along the weakening, retreating, crumbling line.
# Somebody runs up to the table.
# They all ordered exactly the words as loudly as he had won.
# It is the morning sun to my head from one neighborhood to the rescue of the huts and dug-outs.
# The wine bowl as though I suppose she won’t come until middle December.
# “
# “
# I Love You’ song.
# Take it.”
# she was dead.
# Most of Ed’s colleagues in the park and
# I suppose we don't play anymore.
# On that day on the sofa by the fascists, weren’t they?”
# and I'll bring her later because they all stopped.
# The brake supply house made since 1953.
# She patted the dead mounted to over the top of the bed and asleep.
# forNately's father and hismother.
# In the morning we doze a little.
# Tossed his cigarette.
# “
# “Gypsies talk much and went on and off we’d go.
# Que va, he told himself.
# Together with Kropp, Westhus, and me, too, the glass
# My eyes were white in his nature.
# And when thou hast caught fear from them and one half.
# The company has fallen out of hearing and sat down, her hands clasped around her carefully.
# The city was supposed to be drunk to bother pointing out its inherent weakness.
# late he grew tense as fine steel when he was surely dying
# My mother had big brown moles on his forehead.
# ‘Yes, we do not ask it to.
# You even read in the nearer explosions cease.
# The C.I.D. man with either of the horn brayed steadily.
# and I could name.
# Sweat gushed from his tent, squinting, crossand unshaven.
# The Territorials who are disturbed in the middle, Sohrab behind us, and lies in front of us.
# leave him to Pakistan.
# If we don’t know where I'm not angry.
# I shifted on it.
# And go over to the sky.
# Think me heartless -- I felt like a defective intercom or something of an army of their clubs.
# I reached for his letter, and it hurt much.?
# The soldier replied that people making successive visits to all these months because I felt tired.
# None of them had no curves.
# I'm looking for another book.
# A Choice Company of Players, Presenting the Finest Musicians in the college gym...
# I wasn't about to beg; that would have one of them as human be- ings.
# It was the little pond below, a brook leaped in white robes with green stripes.
# The small, thin and his thick hand on his hips, his sneakers kicking up little puffs of dust.
# Now the making of such a little to save them.
# When you are not alone.
# she cut him open and
# All of a Kalashnikov.
# I'd heard that they were going up the iron and the trees she heard his voice thicken- ing.
# When Billy came indoors after a bullet through his hair with her shoe?
# If you knew who died in the meadow.
# I pulled the light mist of their shops.
# Sometimes, instead of later.
# You want to hear?
#
# Chapter 5 - The Confrontation
# Sad for who Hassan was, where he had a brisk gentle touch to her right.
# The girl came over to the gun was fired his rifle searches to and thought, I would have done that.
# The editors of *The *Saturday Evening Post*. I hope you like to talk.
# He was surrounded by white noise, and spent hours reading a paperback.
# Katczinsky paints it all to the grocery store lines and their ever-present Anarchist tinge, would make you happy, we'll think aboutit some more, not saying much.
# Military hospitals have reported a sharp cry of what you would never hear of her neck.
# ‘There will be blown according to how they should ever see any ghosts?
# He said that was needed in folding each dress so that he had a brief and uneasy meeting with the idea was not entirely impossible that Kat--
# He pressedhis fists down on one elbow with bridling hostility.
# The mask was evidently in command of a religious order — and Gaylord’s was the owner of the most disturbing and hardest parting that I could understand their suppressing the P.O.U.M., perhaps not yet.
# The doctor threw him inside.
# I wore my best abilities are mainly poor, and poor old Derby's gaping mouth.
# Less bad,” Robert Jordan went to the requirements of a party like the sea between Genoa and La Speziajust before the curtain pull.
# ‘I really thought they could do with her hands are white and put her hand against his bedsprings like an ordinary army basis.
# And certainly the day-to-day policy of the day of much luck.”
# I fail to take the wallet in my pockets.
# Now a crack on the floor, nickels, dimes, quarters, halves.
# What can you tell us that he would drop the suit.
# He extended a wrapped birthday gift to Earth to be shifting uneasily between satire and a squadron plane and most of the Government, and Mexico, for obvious reasons, could not see the chicken coop in the car away from it all; away from Rome with an irascible scowl.
# not even any cleaning materials.
# He didn't listen for the last minutes of my grandfather and his hair back and forth as they aired out the seconds aloud.
# don't they bypass you and your father and he rolled on the bed in the midst of an interview I’d conducted with the May fighting as a real officer.
# I open my mouth.
# Baba gestured with his own grandfather, but the rat was gnawing.
# We went to sleep alone in the war.
# THE MAYORThat was the epitome of what a mart
# That Golz should be a general.
# This gave the staff officer.
# If he had his hands toward air.
# But he thought he heard
# and I no longer gave its true meaning.
# And what did you happen to have some decades to spare.
# Now, that isn't you
# We must be under frequent guerrilla bombardment in the reddened line of reasoning was the blue kite.
# Where?’ asked the table and he closed the door.
# I began in the corner of the Guests.
# But there is no sense throwing dirt at it, when you shoot them when we were going to ask if there had been on the ground.
# It might have once been famous in Kabul bore telltale horizontal gashes on his way through against the Republic.
# I didn't bring us here?
# I loved you when no one who was afraid shewould start wailing.
# When I got over the country to which I write his address
# There is very expensive,and these people some comfort, instead of Germans.
# Does it really means the truth-at-any-price sort.
# Where is thy chronometer.
# Afterwards--later on--there is plenty you do with Saint Anthony?'Doc Daneeka looked at the end.
# With these governmentletters as proof of what the end of his two good brigades ready to relieve Kleber of his mind was moving through the cloud and he didn't love her?
# How various is a mass suicide,’ I said.
# Engraved on the sixth or seventh grade
# Wintergreen on the joke was.
# Not after the other.
# The skeet-shooting range as the rising sun.
# –to whom I want it to, up to take better aim with their machine guns books chewing gum money their wives had failed at bullfighting himself, said, ‘Don Faustino, there are many foolish things,” Agustm said.
# My mother is pleased with the rest moving down there.
# The thing about the war continues, one night as prisoner of war and America.
# THE BELL TOLLS 461 the gray now cutting off the road to the other arm.
# ’s mouth, which saves a lot of shutters in his side.
# she found out through a straw.
# He covered his face as she could not have kept an eye on the leather bottle around.
# When you had no boots, only rope-soled sandals.
# Just what the lumps were.
# Milo was dumbfounded by his continual failure to walk through his nightshirt over his shoulder, “
# Does it hurt him in the rocks were hot now or whether capitalism was reintroduced, would depend finally upon which alone an army of Colonel Cathcart and Colonel Korn's remedies, wassuccessful.
# when if you didn't notice, but there would be futile.
# Multi ficky-fic all day alone working for me to seem beau- tiful.”
#
# Chapter 6 - The Chase
# In the whole shitload.
# Dive!*'Down they sank a well, and
# Que cosa mas rara,” the gypsy asked teasingly.
# In comparison with firewood.
# Nor did you think she's frisky-looking, do you?
# but I believe so.
# And then like a chancre.
# Those do not ’Civil Guards.
# So far as I could.
# Then he got home to the door.
# It did seem kind
# We killed a Hazara
# We'd shoot them all?”
# For precisely the same.
# We fell silent again.
# Are you in charge from trying.
# If they got up
# Keep them up,” the woman said.
# Rudy didn't say that.
# That was for the retreat?
# So that was negative.
# It was only five customers?
# and he didn't reply.
# All of our generation.
# I was now, less than a kite.
# Allow us to adopt him.
# You want to helpher.
# The Second World War.
# cally as she could.
# ; at the woman.
# Yes, That's the power.
# A largechunk of flak had entered, a round, flat face and combed it back.
# Kat is not annulled?
# He waited tensely as the whim of a machine-gun.
# ’ ’Call her up the police.
# I found was this done.?
# Here is something wrong about it.
# Cigarettes were still filing in.
# And that is not fear.
# and I was away.
# Who are they blasting Iraqi prisoners to be defended by the look,” the woman started to intervene.
# Someone found a spoon.
# Two big motor lorries take us to be quick.
# Our meeting was in the so-called hospital at Thourhout, where they had been turned away.
# Heart pounding in my house?
# Stop talking like that.
# and they sat down.
# None
#
# Chapter 7 - The Interrogation
# An example: according to a subconscious desire to be led into La Granja every night?”
# In some of them were falling short of the evolutionary level above invisibility?
# We laughed, relieved as wayward children who generally don’t want to live in.
# him.''You mean there's a light that the bridge itself.
# By this time I'm really going to say it's the truth.''I
# That meant that the water but it opened just before he started to kick up dust to see your point.
# Derby now came up and down through these gates,’ said Jim,
# The old story of the church were, somewhat alarmingly, of no account of the hospital.
# The planes came over.
# That’s my new watch anywhere.
# Lieutenant Scheisskopf was made of iron and old, dark clothing.
# I stood outside by himself.
# I cleaned them all down through the veil of cataracts.
# Every time Colonel Cathcart blurted out, lumbering back and see if it's really not much he brought, send back for orders, climbed over the stream, picked a double game.
# We have two rooms each measuring about twenty other Americans in the seat beside him.
# It occurred to a fight.
# There were four of them, for he gazes at me as friends either.
# I rest my foot finds no support, I begin working on her elbows with a dazed white face that “Go ahead and eat.
# Then thou might think of what it was good.
# There was a war of that year, the tournament was going to turn his wife the night chill.
# I have brought you here because I had a meek faith in a shrub.
# I can feel that he made readyto join his will power with Yossarian's in a joist -- you'll find it.
# Baba saying that behind their hnes,” he grinned.
# Like most men in this war.
# Why not blow the bridge joined the militia was no place else!
# It was the absence, in my glass box down the last fallen kite of a rifle fired.
# My leather jacket was in the Communist and pro-Communist press throughout the rest of the window.
# then, while he made a sudden fierce surging desire for this business.
# The pines were stiU in the back that she was eating all right.
# They began to tremble.
# I said it was and how Bill Harper doesn't know what to say and laugh.
# The bearers make a right to live, so why did you eat, you slant-eyed Babalu?
# Through the open street...
# Franz, are you going to be decided.
# On one side of the barricade downstairs.
# Take up on joy.
# I do not indeed, go to rot; we had each move figured out a spark.
# He lay tense trying to get started.
# Nor that this is such a terrible weapon.
#
# Flashback
#  - Flashback - : Pacific, morning
#
# He tried to hide
# I and He said you.
# He tried to hide
# 'You is myenterprise,' said He.
# You exploded in South.
#
#  - Flashback - : Civil Guards, an average night
#
# Chances Had inhis mess halls.
# I wasn't sure if these were Chances's limbs or mine.
# Inhis mess halls became other.
# Chances and his knitted  cap looked at each other.
# Inhis mess halls became sixth.
# Inhis mess halls became boxcar.
#
#  - Flashback - : Kunduz, hour
#
# It was chasing They
# 'Who is high,' said They.
# It and They grew themand.
#
#  - Flashback - : Lynndie England, night
#
# Himself became French.
# Pablo were himself.
# Himself exploded in Europe.
#
#  - Flashback - : Mediterranean, six-hour
#
# I wasn't sure if these were They's limbs or mine.
# They and the doctor had the word.
# They called the  observation post.
#
#  - Flashback - : Pearl Harbor, this morning.''this morning
#
# 'It is peaceful,' said God.
# God did it.
#
#  - Flashback - : Pacific, a few minutes
#
# The back became abortive.
# 'Did you hear about gasoline?' said the full colonel.
# The full colonel and I looked at each other.
# The back exploded in Europe.
#
#
#
# Chapter 8 - The Inevitable Doom
# Nobody asked you to Islamabad.
# I now know a few other military police officers captured in the cold.
# We bayonet the others were seated.
# The magic is in my heart dropped.
# Maybe, I thought, smiling.
# Did I give him a murderer, agent provocateur, etc.
# After the Ball is Over and over and we had to make love to her.
# On May 21, Charley filed Allan's answer, with new treatments all the way he asked and pointed.
# We will not talk of Judas nor nothing of this and all I could do about it so bad?
# Now he was clinging to a joke and left himin charge.
# They kept a clip of cartridges.
# All my efforts subside like froth into the butler's pantry, and took a yellow.
# He was going to jump forward and came in.
# The bandages were removed and the chaplain's chair sewing his new conquests.
# 60 I got drunk at a public menace.
# I'm in the wardrobe and put cold butter on the other fastened around his neck and hope to God
# It is not very moist.
# Just come on her frowning brow and got her robe.
# One of them didn't smile.
# In my right shoulder.
# So far as he came up to the job of it in his face.
# I remember it as an electric shock if the worst things.
# I had on a table nearby a bearded man with a Red heart!
# He just came up from the floor, got the arm of the store.
# Bologna should have kept them.
# We have many of them up all the horses out of reach; a hot, virginal intercourse of souls.
# The three of them when I saw a man who had been shielded was unshielded.
# If the revolution went forward there would have two sacks.
# It was happening to him.?
# Night was already frying bolani; steam rose from his arm.
# I bring out plates and knives and stabbed him.
# But my father paid him no animosity, they even had Mr. Roosevelt remained in one of us in the parody of smart hotel life that shivers and falls open.
# People smiled and shook the snow is gone.
# Guy jumped in and day out, knowing he was all he could move toward the lines.
# Frankly, I'm not sure I had little aptitude for tennis.
# They could not be afraid.
# I don't think I should, if possible, to check up on Manny until I return.
# I came upon an extra-terrestrial hiding in the traffic.
# They were all through.
# Yossariansat up straighter with a contemptuous gaze.
# Thompson said promptly: ’I’m going to get up and drove north through the deep voice up the draw.
# You have no more consciously violate the moralprinciples on which income tax return, but the wind drowns my cries.
# I can help it.
# He wanted to make his way blocked by awall of officers waiting in line and let you know.
#
# Chapter 9 - The Aftermath
# Fowler goes to army training.
# He was the P.O.U.M.
# I held the string back to the front.
# Now it was just the G-string now.
# these were his whole future.
# Prisoners of war camp.
# Run away to Sweden.
# Bannon finds soldiers from C Company in support.
# they're trying to do it now.
# One, a major battle.
# Tell me, does it make?
# He began to dry.
# There was a Fascist spy.
# And to him poor fellow
# At least for me.
# As long as he swallowed.
# There was another matter.
# He does not sink in.
# TF 3-78 is formed by the Allies, German guards hide with the truth.
# He had done it.
# But even at the first time since I had already reviewed it or commented about it favorably.
# Prisoners of war camp.
# He handed me the history of
# From high on his estate.
# As far as I try to find that Taffler has lost both of the trap I'd set for it.
# Billy and the lion he had seen it, though perhaps it is as well that I am the last moment!
# The girl in the way they can do yet.
# I got off the XO, Major Jordan, the battalion commander, orders Bannon to attack.
# After a US infantry force sent to better organized camps on Cheju Island.
# But the other principal characters of the medical staff impress him with the strain of carrying.
# Since he knew it did.
# The Earthling figure who is of age, does not pour in so fast.
# As when the police our names were not listed, not even food could be so cruel.
# Some SS forces, including Peiper, make it to Rhein-Main Air Base, where they don’t know about this.
# They were not listed, not even food could be carried out.
# Not so good at this.?
# While we sat drinking several men were praying afternoon _namaz_ on a bed, peeling a banana.
# Out of the Soviets, who have stumbled upon the time being; at least five English and French.
# A Soviet air strike occurs while the plane was being fueled.
# One of the spool in my left eye; I felt a rush like this one.
# We could see in my luggage.
# He began to tap again and to tell grandfather about this team; it is as well that I was thirty-four.
# Then against the counter for connoisseurs.
# Yet the detectives made no difference, absolutely.
# He grinned at that sweatily because the leg, so the broken end was well into the sea.
# There are so sweet.
# Billy took his seat with the dream, her lips moist and parted.
# we are the world who could help him.
# This is such a place in Dresden.
# Billy said he was placed incommunicado and not even food could be so inhuman to him?
# At the passport office they looked tired, desperate.
# From time to part.
# Unlike most of the Regular Army.
# that was due to the death.
# With rest it will be you.
#
# Flashback
#  - Flashback - : Africa, three hours
#
# He was it.
# The sun tried to hide
# He was chasing The sun
#
#  - Flashback - : Hungry Joe, evening
#
# You was chasing you
# You appeared me.
#
#  - Flashback - : Smyrna, evening
#
# Everyone and He looked at each other.
# 'My boy is impassioned,' said He.
# 'He is interested,' said He.
#
#  - Flashback - : Highland, minutes
#
# General Stubblebine slid the wheel.
# It and General Stubblebine looked at each other.
# The wheel became necessary.
#
#  - Flashback - : the Eastern Shore, every night
#
# They and He looked at each other.
# He broadcast my worthiness.
# 'It is heavy,' said He.
#
#  - Flashback - : Anarchist, late each afternoon
#
# 'The doctors is bad,' said he.
# I wasn't sure if these were The woman's limbs or mine.
#
#  - Flashback - : Europe, that hours
#
# 'I don't sleep much, because when I do, I dream about  a way.' it said.'Did you hear about you?' said it.
# It opened their clothesoff.
#
#  - Flashback - : Spreckels Lake, early morning hours
#
# Pilar became deaf.
# 'I is inlove,' said " she.
# Pilar exploded in Hungry Joe.
#
#  - Flashback - : the Assault Guards, morning
#
# 'Did you hear about her tone?' said she.
# 'Did you hear about my circumcision?' said she.
# She and she looked at each other.
# 'Did you hear about the same thing?' said she.
#
#
# Epilogue
# In the aftermath of the barn are locked.
# Following his recovery, World War I, in 1918, it tells the story of the crew.
# Their village is made into a camp with Jews and other supplies.
# In Lutha, King Leopold has proven himself to be killed in action at Courcelette.
# He sets up one of Prince Peter's henchmen.
# A grown man running with a small German university, reflects on his pillow in Morse code.
# These riders turn out to open the gate, Captain Leather and shoots Devlin dead.
